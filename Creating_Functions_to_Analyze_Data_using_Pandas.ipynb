# %% [markdown]
# <a href="https://colab.research.google.com/github/Masehanridegreecollege/Python-mini-project-/blob/main/Creating_Functions_to_Analyze_Data_using_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
datasetpath='/content/matches_1930_2022.csv'

# %%
df=pd.read_csv(datasetpath)

# %%
df
# Out:
#          home_team away_team  home_score  home_xg  home_penalty  away_score  \
# 0        Argentina    France           3      3.3           4.0           3
# 1          Croatia   Morocco           2      0.7           NaN           1
# 2           France   Morocco           2      2.0           NaN           0
# 3        Argentina   Croatia           3      2.3           NaN           0
# 4          Morocco  Portugal           1      1.4           NaN           0
# ..             ...       ...         ...      ...           ...         ...
# 959      Argentina    France           1      NaN           NaN           0
# 960     Yugoslavia    Brazil           2      NaN           NaN           1
# 961        Romania      Peru           3      NaN           NaN           1
# 962  United States   Belgium           3      NaN           NaN           0
# 963         France    Mexico           4      NaN           NaN           1
#
#      away_xg  away_penalty      home_manager          home_captain  ...  \
# 0        2.2           2.0    Lionel Scaloni          Lionel Messi  ...
# 1        1.2           NaN      Zlatko Dalić           Luka Modrić  ...
# 2        0.9           NaN  Didier Deschamps           Hugo Lloris  ...
# 3        0.5           NaN    Lionel Scaloni          Lionel Messi  ...
# 4        0.9           NaN   Hoalid Regragui          Romain Saïss  ...
# ..       ...           ...               ...                   ...  ...
# 959      NaN           NaN  Francisco Olazar       Manuel Ferreira  ...
# 960      NaN           NaN   Bosko Simonovic       Milutin Ivković  ...
# 961      NaN           NaN     Octav Luchide          Emerich Vogl  ...
# 962      NaN           NaN        Bob Millar            Tom Florie  ...
# 963      NaN           NaN     Raoul Caudron  Alexandre Villaplane  ...
#
#     home_penalty_shootout_miss_long  \
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3                               NaN
# 4                               NaN
# ..                              ...
# 959                             NaN
# 960                             NaN
# 961                             NaN
# 962                             NaN
# 963                             NaN
#
#                        away_penalty_shootout_miss_long  home_red_card  \
# 0    ['3|1:1|Kingsley Coman', '5|2:1|Aurélien Tchou...            NaN
# 1                                                  NaN            NaN
# 2                                                  NaN            NaN
# 3                                                  NaN            NaN
# 4                                                  NaN            NaN
# ..                                                 ...            ...
# 959                                                NaN            NaN
# 960                                                NaN            NaN
# 961                                                NaN            NaN
# 962                                                NaN            NaN
# 963                                                NaN            NaN
#
#             away_red_card   home_yellow_red_card away_yellow_red_card  \
# 0                     NaN                    NaN                  NaN
# 1                     NaN                    NaN                  NaN
# 2                     NaN                    NaN                  NaN
# 3                     NaN                    NaN                  NaN
# 4                     NaN  Walid Cheddira · 90+3                  NaN
# ..                    ...                    ...                  ...
# 959                   NaN                    NaN                  NaN
# 960                   NaN                    NaN                  NaN
# 961  Plácido Galindo · 70                    NaN                  NaN
# 962                   NaN                    NaN                  NaN
# 963                   NaN                    NaN                  NaN
#
#                                  home_yellow_card_long  \
# 0    ['45+7&rsquor;|2:0|Enzo Fernández', '90+8&rsqu...
# 1                                                  NaN
# 2                                                  NaN
# 3    ['68&rsquor;|2:0|Cristian Romero', '71&rsquor;...
# 4    ['70&rsquor;|1:0|Achraf Dari', '90+1&rsquor;|1...
# ..                                                 ...
# 959                                                NaN
# 960                                                NaN
# 961                                                NaN
# 962                                                NaN
# 963                                                NaN
#
#                                  away_yellow_card_long  \
# 0    ['55&rsquor;|2:0|Adrien Rabiot', '87&rsquor;|2...
# 1    ['69&rsquor;|2:1|Azzedine Ounahi', '84&rsquor;...
# 2                    ['27&rsquor;|1:0|Sofiane Boufal']
# 3    ['32&rsquor;|0:0|Mateo Kovačić', '32&rsquor;|0...
# 4                           ['87&rsquor;|1:0|Vitinha']
# ..                                                 ...
# 959                                                NaN
# 960                                                NaN
# 961                                                NaN
# 962                                                NaN
# 963                                                NaN
#
#                                home_substitute_in_long  \
# 0    ['64&rsquor;|2:0|Marcos Acuña|for Ángel Di Mar...
# 1    ['61&rsquor;|2:1|Nikola Vlašić|for Andrej Kram...
# 2    ['65&rsquor;|1:0|Marcus Thuram|for Olivier Gir...
# 3    ['62&rsquor;|2:0|Lisandro Martínez|for Leandro...
# 4    ['57&rsquor;|1:0|Achraf Dari|for Romain Saïss'...
# ..                                                 ...
# 959                                                NaN
# 960                                                NaN
# 961                                                NaN
# 962                                                NaN
# 963                                                NaN
#
#                                away_substitute_in_long
# 0    ['41&rsquor;|2:0|Randal Kolo Muani|for Ousmane...
# 1    ['46&rsquor;|2:1|Ilias Chair|for Abdelhamid Sa...
# 2    ['21&rsquor;|1:0|Selim Amallah|for Romain Saïs...
# 3    ['46&rsquor;|2:0|Mislav Oršić|for Borna Sosa',...
# 4    ['51&rsquor;|1:0|João Cancelo|for Raphaël Guer...
# ..                                                 ...
# 959                                                NaN
# 960                                                NaN
# 961                                                NaN
# 962                                                NaN
# 963                                                NaN
#
# [964 rows x 44 columns]

# %%
df.columns
# Out:
# Index(['home_team', 'away_team', 'home_score', 'home_xg', 'home_penalty',
#        'away_score', 'away_xg', 'away_penalty', 'home_manager', 'home_captain',
#        'away_manager', 'away_captain', 'Attendance', 'Venue', 'Officials',
#        'Round', 'Date', 'Score', 'Referee', 'Notes', 'Host', 'Year',
#        'home_goal', 'away_goal', 'home_goal_long', 'away_goal_long',
#        'home_own_goal', 'away_own_goal', 'home_penalty_goal',
#        'away_penalty_goal', 'home_penalty_miss_long', 'away_penalty_miss_long',
#        'home_penalty_shootout_goal_long', 'away_penalty_shootout_goal_long',
#        'home_penalty_shootout_miss_long', 'away_penalty_shootout_miss_long',
#        'home_red_card', 'away_red_card', 'home_yellow_red_card',
#        'away_yellow_red_card', 'home_yellow_card_long',
#        'away_yellow_card_long', 'home_substitute_in_long',
#        'away_substitute_in_long'],
#       dtype='object')

# %%
df['home_team'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 964 entries, 0 to 963
# Series name: home_team
# Non-Null Count  Dtype
# --------------  -----
# 964 non-null    object
# dtypes: object(1)
# memory usage: 7.7+ KB

# %%
df['home_team'].value_counts()
# Out:
# home_team
# Brazil                    85
# Argentina                 59
# Italy                     57
# England                   40
# Germany                   40
#                           ..
# Jamaica                    1
# FR Yugoslavia              1
# Angola                     1
# Trinidad and Tobago        1
# Bosnia and Herzegovina     1
# Name: count, Length: 82, dtype: int64

# %%
df['Date'].value_counts()
# Out:
# Date
# 1958-06-15    8
# 1958-06-08    8
# 1934-05-27    8
# 1958-06-11    7
# 1938-06-05    6
#              ..
# 2006-07-08    1
# 2006-07-05    1
# 2006-07-04    1
# 1966-07-25    1
# 2022-12-18    1
# Name: count, Length: 378, dtype: int64

# %%
df['Score'].value_counts()
# Out:
# Score
# 1–0            118
# 2–1            107
# 1–1             75
# 2–0             71
# 0–0             66
#               ...
# (4) 2–2 (3)      1
# (3) 0–0 (2)      1
# (4) 2–2 (5)      1
# (4) 1–1 (3)      1
# 6–5              1
# Name: count, Length: 71, dtype: int64

# %%
ScoredAboveZero=df['Score']> '0-0'

# %%
df[ScoredAboveZero]
# Out:
#          home_team away_team  home_score  home_xg  home_penalty  away_score  \
# 1          Croatia   Morocco           2      0.7           NaN           1
# 2           France   Morocco           2      2.0           NaN           0
# 3        Argentina   Croatia           3      2.3           NaN           0
# 4          Morocco  Portugal           1      1.4           NaN           0
# 5          England    France           1      2.4           NaN           2
# ..             ...       ...         ...      ...           ...         ...
# 959      Argentina    France           1      NaN           NaN           0
# 960     Yugoslavia    Brazil           2      NaN           NaN           1
# 961        Romania      Peru           3      NaN           NaN           1
# 962  United States   Belgium           3      NaN           NaN           0
# 963         France    Mexico           4      NaN           NaN           1
#
#      away_xg  away_penalty      home_manager          home_captain  ...  \
# 1        1.2           NaN      Zlatko Dalić           Luka Modrić  ...
# 2        0.9           NaN  Didier Deschamps           Hugo Lloris  ...
# 3        0.5           NaN    Lionel Scaloni          Lionel Messi  ...
# 4        0.9           NaN   Hoalid Regragui          Romain Saïss  ...
# 5        0.9           NaN  Gareth Southgate            Harry Kane  ...
# ..       ...           ...               ...                   ...  ...
# 959      NaN           NaN  Francisco Olazar       Manuel Ferreira  ...
# 960      NaN           NaN   Bosko Simonovic       Milutin Ivković  ...
# 961      NaN           NaN     Octav Luchide          Emerich Vogl  ...
# 962      NaN           NaN        Bob Millar            Tom Florie  ...
# 963      NaN           NaN     Raoul Caudron  Alexandre Villaplane  ...
#
#     home_penalty_shootout_miss_long away_penalty_shootout_miss_long  \
# 1                               NaN                             NaN
# 2                               NaN                             NaN
# 3                               NaN                             NaN
# 4                               NaN                             NaN
# 5                               NaN                             NaN
# ..                              ...                             ...
# 959                             NaN                             NaN
# 960                             NaN                             NaN
# 961                             NaN                             NaN
# 962                             NaN                             NaN
# 963                             NaN                             NaN
#
#      home_red_card         away_red_card   home_yellow_red_card  \
# 1              NaN                   NaN                    NaN
# 2              NaN                   NaN                    NaN
# 3              NaN                   NaN                    NaN
# 4              NaN                   NaN  Walid Cheddira · 90+3
# 5              NaN                   NaN                    NaN
# ..             ...                   ...                    ...
# 959            NaN                   NaN                    NaN
# 960            NaN                   NaN                    NaN
# 961            NaN  Plácido Galindo · 70                    NaN
# 962            NaN                   NaN                    NaN
# 963            NaN                   NaN                    NaN
#
#     away_yellow_red_card                              home_yellow_card_long  \
# 1                    NaN                                                NaN
# 2                    NaN                                                NaN
# 3                    NaN  ['68&rsquor;|2:0|Cristian Romero', '71&rsquor;...
# 4                    NaN  ['70&rsquor;|1:0|Achraf Dari', '90+1&rsquor;|1...
# 5                    NaN                   ['90&rsquor;|1:2|Harry Maguire']
# ..                   ...                                                ...
# 959                  NaN                                                NaN
# 960                  NaN                                                NaN
# 961                  NaN                                                NaN
# 962                  NaN                                                NaN
# 963                  NaN                                                NaN
#
#                                  away_yellow_card_long  \
# 1    ['69&rsquor;|2:1|Azzedine Ounahi', '84&rsquor;...
# 2                    ['27&rsquor;|1:0|Sofiane Boufal']
# 3    ['32&rsquor;|0:0|Mateo Kovačić', '32&rsquor;|0...
# 4                           ['87&rsquor;|1:0|Vitinha']
# 5    ['43&rsquor;|0:1|Antoine Griezmann', '47&rsquo...
# ..                                                 ...
# 959                                                NaN
# 960                                                NaN
# 961                                                NaN
# 962                                                NaN
# 963                                                NaN
#
#                                home_substitute_in_long  \
# 1    ['61&rsquor;|2:1|Nikola Vlašić|for Andrej Kram...
# 2    ['65&rsquor;|1:0|Marcus Thuram|for Olivier Gir...
# 3    ['62&rsquor;|2:0|Lisandro Martínez|for Leandro...
# 4    ['57&rsquor;|1:0|Achraf Dari|for Romain Saïss'...
# 5    ['79&rsquor;|1:2|Raheem Sterling|for Bukayo Sa...
# ..                                                 ...
# 959                                                NaN
# 960                                                NaN
# 961                                                NaN
# 962                                                NaN
# 963                                                NaN
#
#                                away_substitute_in_long
# 1    ['46&rsquor;|2:1|Ilias Chair|for Abdelhamid Sa...
# 2    ['21&rsquor;|1:0|Selim Amallah|for Romain Saïs...
# 3    ['46&rsquor;|2:0|Mislav Oršić|for Borna Sosa',...
# 4    ['51&rsquor;|1:0|João Cancelo|for Raphaël Guer...
# 5    ['79&rsquor;|1:2|Kingsley Coman|for Ousmane De...
# ..                                                 ...
# 959                                                NaN
# 960                                                NaN
# 961                                                NaN
# 962                                                NaN
# 963                                                NaN
#
# [929 rows x 44 columns]

# %%
ScoredByBrazil=df['home_team']=='Brazil'

# %%
df[ScoredAboveZero & ScoredByBrazil]
# Out:
#     home_team       away_team  home_score  home_xg  home_penalty  away_score  \
# 11     Brazil  Korea Republic           4      3.6           NaN           1
# 34     Brazil     Switzerland           1      1.0           NaN           0
# 51     Brazil          Serbia           2      2.4           NaN           0
# 71     Brazil         Belgium           1      2.8           NaN           2
# 74     Brazil          Mexico           2      2.7           NaN           0
# ..        ...             ...         ...      ...           ...         ...
# 911    Brazil          Sweden           4      NaN           NaN           2
# 915    Brazil  Czechoslovakia           2      NaN           NaN           1
# 917    Brazil  Czechoslovakia           1      NaN           NaN           1
# 926    Brazil          Poland           6      NaN           NaN           5
# 951    Brazil         Bolivia           4      NaN           NaN           0
#
#      away_xg  away_penalty         home_manager               home_captain  \
# 11       0.5           NaN                 Tite               Thiago Silva
# 34       0.3           NaN                 Tite               Thiago Silva
# 51       0.2           NaN                 Tite               Thiago Silva
# 71       0.5           NaN                 Tite                    Miranda
# 74       0.7           NaN                 Tite               Thiago Silva
# ..       ...           ...                  ...                        ...
# 911      NaN           NaN       Ademar Pimenta                   Leônidas
# 915      NaN           NaN       Ademar Pimenta                   Leônidas
# 917      NaN           NaN       Ademar Pimenta  Martim Mércio da Silveira
# 926      NaN           NaN       Ademar Pimenta  Martim Mércio da Silveira
# 951      NaN           NaN  Pindaro De Carvalho                  Preguinho
#
#      ... home_penalty_shootout_miss_long away_penalty_shootout_miss_long  \
# 11   ...                             NaN                             NaN
# 34   ...                             NaN                             NaN
# 51   ...                             NaN                             NaN
# 71   ...                             NaN                             NaN
# 74   ...                             NaN                             NaN
# ..   ...                             ...                             ...
# 911  ...                             NaN                             NaN
# 915  ...                             NaN                             NaN
# 917  ...                             NaN                             NaN
# 926  ...                             NaN                             NaN
# 951  ...                             NaN                             NaN
#
#                               home_red_card  away_red_card  \
# 11                                      NaN            NaN
# 34                                      NaN            NaN
# 51                                      NaN            NaN
# 71                                      NaN            NaN
# 74                                      NaN            NaN
# ..                                      ...            ...
# 911                                     NaN            NaN
# 915                                     NaN            NaN
# 917  Zezé Procópio · 14|Arthur Machado · 89  Jan Říha · 89
# 926                                     NaN            NaN
# 951                                     NaN            NaN
#
#     home_yellow_red_card away_yellow_red_card  \
# 11                   NaN                  NaN
# 34                   NaN                  NaN
# 51                   NaN                  NaN
# 71                   NaN                  NaN
# 74                   NaN                  NaN
# ..                   ...                  ...
# 911                  NaN                  NaN
# 915                  NaN                  NaN
# 917                  NaN                  NaN
# 926                  NaN                  NaN
# 951                  NaN                  NaN
#
#                                  home_yellow_card_long  \
# 11                                                 NaN
# 34                             ['52&rsquor;|0:0|Fred']
# 51                                                 NaN
# 71   ['85&rsquor;|1:2|Fernandinho', '90&rsquor;|1:2...
# 74   ['43&rsquor;|0:0|Filipe Luís', '59&rsquor;|1:0...
# ..                                                 ...
# 911                                                NaN
# 915                                                NaN
# 917                                                NaN
# 926                                                NaN
# 951                                                NaN
#
#                                  away_yellow_card_long  \
# 11                   ['44&rsquor;|4:0|Jung Woo-young']
# 34                    ['50&rsquor;|0:0|Fabian Rieder']
# 51   ['7&rsquor;|0:0|Strahinja Pavlović', '49&rsquo...
# 71   ['47&rsquor;|0:2|Toby Alderweireld', '71&rsquo...
# 74   ['38&rsquor;|0:0|Edson Álvarez', '55&rsquor;|1...
# ..                                                 ...
# 911                                                NaN
# 915                                                NaN
# 917                                                NaN
# 926                                                NaN
# 951                                                NaN
#
#                                home_substitute_in_long  \
# 11   ['63&rsquor;|4:0|Dani Alves|for Éder Militão',...
# 34   ['46&rsquor;|0:0|Rodrygo|for Lucas Paquetá', '...
# 51   ['75&rsquor;|2:0|Fred|for Lucas Paquetá', '76&...
# 71   ['46&rsquor;|0:2|Roberto Firmino|for Willian',...
# 74   ['80&rsquor;|1:0|Fernandinho|for Paulinho', '8...
# ..                                                 ...
# 911                                                NaN
# 915                                                NaN
# 917                                                NaN
# 926                                                NaN
# 951                                                NaN
#
#                                away_substitute_in_long
# 11   ['46&rsquor;|4:0|Hong Chul|for Kim Jin-su', '4...
# 34   ['59&rsquor;|0:0|Edimilson Fernandes|for Ruben...
# 51   ['57&rsquor;|0:0|Ivan Ilić|for Nemanja Gudelj'...
# 71   ['83&rsquor;|1:2|Thomas Vermaelen|for Nacer Ch...
# 74   ['46&rsquor;|0:0|Miguel Layún|for Rafael Márqu...
# ..                                                 ...
# 911                                                NaN
# 915                                                NaN
# 917                                                NaN
# 926                                                NaN
# 951                                                NaN
#
# [81 rows x 44 columns]

# %%
brazildf=df[ScoredAboveZero & ScoredByBrazil].sort_values(by='home_score',ascending=True)

# %%
brazildf
# Out:
#     home_team       away_team  home_score  home_xg  home_penalty  away_score  \
# 512    Brazil       Argentina           0      NaN           NaN           1
# 261    Brazil          France           0      NaN           NaN           1
# 695    Brazil          Poland           0      NaN           NaN           1
# 817    Brazil  Czechoslovakia           0      NaN           NaN           0
# 679    Brazil           Spain           0      NaN           NaN           0
# ..        ...             ...         ...      ...           ...         ...
# 887    Brazil          Mexico           5      NaN           NaN           0
# 831    Brazil          France           5      NaN           NaN           2
# 891    Brazil           Spain           6      NaN           NaN           1
# 926    Brazil          Poland           6      NaN           NaN           5
# 893    Brazil          Sweden           7      NaN           NaN           1
#
#      away_xg  away_penalty             home_manager  \
# 512      NaN           NaN       Sebastiao Lazaroni
# 261      NaN           NaN  Carlos Alberto Parreira
# 695      NaN           NaN            Mario Zagallo
# 817      NaN           NaN           Aymore Moreira
# 679      NaN           NaN         Claudio Coutinho
# ..       ...           ...                      ...
# 887      NaN           NaN             Zeze Moreira
# 831      NaN           NaN            Vicente Feola
# 891      NaN           NaN             Flavio Costa
# 926      NaN           NaN           Ademar Pimenta
# 893      NaN           NaN             Flavio Costa
#
#                   home_captain  ... home_penalty_shootout_miss_long  \
# 512              Ricardo Gomes  ...                             NaN
# 261                        NaN  ...                             NaN
# 695              Marinho Peres  ...                             NaN
# 817                Mauro Ramos  ...                             NaN
# 679               Émerson Leão  ...                             NaN
# ..                         ...  ...                             ...
# 887                      Bauer  ...                             NaN
# 831         Hilderaldo Bellini  ...                             NaN
# 891           Augusto da Costa  ...                             NaN
# 926  Martim Mércio da Silveira  ...                             NaN
# 893           Augusto da Costa  ...                             NaN
#
#     away_penalty_shootout_miss_long       home_red_card away_red_card  \
# 512                             NaN  Ricardo Gomes · 85           NaN
# 261                             NaN                 NaN           NaN
# 695                             NaN                 NaN           NaN
# 817                             NaN                 NaN           NaN
# 679                             NaN                 NaN           NaN
# ..                              ...                 ...           ...
# 887                             NaN                 NaN           NaN
# 831                             NaN                 NaN           NaN
# 891                             NaN                 NaN           NaN
# 926                             NaN                 NaN           NaN
# 893                             NaN                 NaN           NaN
#
#     home_yellow_red_card away_yellow_red_card  \
# 512                  NaN                  NaN
# 261                  NaN                  NaN
# 695                  NaN                  NaN
# 817                  NaN                  NaN
# 679                  NaN                  NaN
# ..                   ...                  ...
# 887                  NaN                  NaN
# 831                  NaN                  NaN
# 891                  NaN                  NaN
# 926                  NaN                  NaN
# 893                  NaN                  NaN
#
#                                  home_yellow_card_long  \
# 512  ['40&rsquor;|0:0|Ricardo Rocha', '50&rsquor;|0...
# 261  ['25&rsquor;|0:0|Cafú', '45&rsquor;|0:0|Juan',...
# 695                       ['76&rsquor;|0:1|Jairzinho']
# 817                                                NaN
# 679                                                NaN
# ..                                                 ...
# 887                                                NaN
# 831                                                NaN
# 891                           ['1&rsquor;|0:0|Bigode']
# 926                                                NaN
# 893                                                NaN
#
#                                  away_yellow_card_long  \
# 512  ['27&rsquor;|0:0|Pedro Monzón', '28&rsquor;|0:...
# 261  ['74&rsquor;|0:1|Willy Sagnol', '87&rsquor;|0:...
# 695               ['71&rsquor;|0:0|Henryk Kasperczak']
# 817                                                NaN
# 679                     ['1&rsquor;|0:0|Eugenio Leal']
# ..                                                 ...
# 887                                                NaN
# 831                                                NaN
# 891                                                NaN
# 926                                                NaN
# 893                                                NaN
#
#                                home_substitute_in_long  \
# 512  ['83&rsquor;|0:1|Silas Pereira', '83&rsquor;|0...
# 261  ['63&rsquor;|0:1|Adriano|for Juninho Pernambuc...
# 695   ['66&rsquor;|0:0|Mirandinha|for Ademir da Guia']
# 817                                                NaN
# 679  ['70&rsquor;|0:0|Gilberto Alves|for Nelinho', ...
# ..                                                 ...
# 887                                                NaN
# 831                                                NaN
# 891                                                NaN
# 926                                                NaN
# 893                                                NaN
#
#                                away_substitute_in_long
# 512  ['61&rsquor;|0:0|Gabriel Calderón|for Pedro Tr...
# 261  ['77&rsquor;|0:1|Sidney Govou|for Franck Ribér...
# 695  ['73&rsquor;|0:0|Lesław Ćmikiewicz|for Henryk ...
# 817                                                NaN
# 679  ['51&rsquor;|0:0|Antonio Biosca|for Migueli', ...
# ..                                                 ...
# 887                                                NaN
# 831                                                NaN
# 891                                                NaN
# 926                                                NaN
# 893                                                NaN
#
# [81 rows x 44 columns]

# %%
brazildf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 81 entries, 512 to 893
# Data columns (total 44 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   home_team                        81 non-null     object
#  1   away_team                        81 non-null     object
#  2   home_score                       81 non-null     int64
#  3   home_xg                          7 non-null      float64
#  4   home_penalty                     0 non-null      float64
#  5   away_score                       81 non-null     int64
#  6   away_xg                          7 non-null      float64
#  7   away_penalty                     0 non-null      float64
#  8   home_manager                     81 non-null     object
#  9   home_captain                     59 non-null     object
#  10  away_manager                     81 non-null     object
#  11  away_captain                     59 non-null     object
#  12  Attendance                       81 non-null     int64
#  13  Venue                            81 non-null     object
#  14  Officials                        64 non-null     object
#  15  Round                            81 non-null     object
#  16  Date                             81 non-null     object
#  17  Score                            81 non-null     object
#  18  Referee                          64 non-null     object
#  19  Notes                            3 non-null      object
#  20  Host                             81 non-null     object
#  21  Year                             81 non-null     int64
#  22  home_goal                        71 non-null     object
#  23  away_goal                        38 non-null     object
#  24  home_goal_long                   71 non-null     object
#  25  away_goal_long                   38 non-null     object
#  26  home_own_goal                    2 non-null      object
#  27  away_own_goal                    2 non-null      object
#  28  home_penalty_goal                8 non-null      object
#  29  away_penalty_goal                8 non-null      object
#  30  home_penalty_miss_long           0 non-null      object
#  31  away_penalty_miss_long           0 non-null      object
#  32  home_penalty_shootout_goal_long  0 non-null      object
#  33  away_penalty_shootout_goal_long  0 non-null      object
#  34  home_penalty_shootout_miss_long  0 non-null      object
#  35  away_penalty_shootout_miss_long  0 non-null      object
#  36  home_red_card                    4 non-null      object
#  37  away_red_card                    3 non-null      object
#  38  home_yellow_red_card             1 non-null      object
#  39  away_yellow_red_card             3 non-null      object
#  40  home_yellow_card_long            43 non-null     object
#  41  away_yellow_card_long            47 non-null     object
#  42  home_substitute_in_long          51 non-null     object
#  43  away_substitute_in_long          55 non-null     object
# dtypes: float64(4), int64(4), object(36)
# memory usage: 28.5+ KB

# %%
# %matplotlib inline

# %%
from matplotlib import pyplot as plt

# %%
brazildf.plot(x='home_score',y='away_score',kind='scatter')
plt.xlabel('Home Score')
plt.ylabel('Away Score')
plt.legend('Takeaway')
plt.title('Brazil Matches')
plt.show()

# %%
brazildf.plot(x='Year',y='home_score',kind='hexbin')
plt.xlabel('Year')
plt.ylabel('Home Score')
plt.legend('Takeaway')
plt.title('Brazil Matches')
plt.show()

# %%
def AnalyzeFrance():
  matchesplayed=df['home_team'].value_counts()['France']
  print(f'Total Number of matches played by France is :{matchesplayed}')

# %%
AnalyzeFrance()
# Out:
# Total Number of matches played by France is :38

# %%
def AnalyzeTowns():
  TownData=df['home_team'].value_counts()
  for _ in TownData.index:
    print(f'Total Number of matches played by{_}is:{TownData}[_]')

# %%
AnalyzeTowns()
# Out:
# Total Number of matches played byBrazilis:home_team
# Brazil                    85
# Argentina                 59
# Italy                     57
# England                   40
# Germany                   40
#                           ..
# Jamaica                    1
# FR Yugoslavia              1
# Angola                     1
# Trinidad and Tobago        1
# Bosnia and Herzegovina     1
# Name: count, Length: 82, dtype: int64[_]
# Total Number of matches played byArgentinais:home_team
# Brazil                    85
# Argentina                 59
# Italy                     57
# England                   40
# Germany                   40
#                           ..
# Jamaica                    1
# FR Yugoslavia              1
# Angola                     1
# Trinidad and Tobago        1
# Bosnia and Herzegovina     1
# Name: count, Length: 82, dtype: int64[_]
# Total Number of matches played byItalyis:home_team
# Brazil                    85
# Argentina                 59
# Italy                     57
# England                   40
# Germany                   40
#                           ..
# Jamaica                    1
# FR Yugoslavia              1
# Angola                     1
# Trinidad and Tobago        1
# Bosnia and Herzegovina     1
# Name: count, Length: 82, dtype: int64[_]
# Total Number of matches played byEnglandis:home_team
# Brazil                    85
# Argentina                 59
# Italy                     57
# England                   40
# Germany                   40
#                           ..
# Jamaica                    1
# FR Yugoslavia              1
# Angola                     1
# Trinidad and Tobago        1
# Bosnia and Herzegovina     1
# Name: count, Length: 82, dtype: int64[_]
# Total Number of matches played byGermanyis:home_team
# Brazil                    85
# Argentina                 59
# Italy                     57
# England                   40
# Germany                   40
#                           ..
# Jamaica                    1
# FR Yugoslavia              1
# Angola                     1
# Trinidad and Tobago        1
# Bosnia and Herzegovina     1
# Name: count, Length: 82, dtype: int64[_]
# Total Number of matches played byFranceis:home_team
# Brazil                    85
# Argentina                 59
# Italy                     57
# England                   40
# Germany                   40
#                           ..
# Jamaica                    1
# FR Yugoslavia              1
# Angola                     1
# Trinidad and Tobago        1
# Bosnia and Herzegovina     1
# Name: count, Length: 82, dtype: int64[_]
# Total Number of matches played byWest Germanyis:home_team
# Brazil                    85
# Argentina                 59
# Italy                     57
# England                   40
# Germany                   40
#                           ..
# Jamaica                    1
# FR Yugoslavia              1
# Angola                     1
# Trinidad and Tobago        1
# Bosnia and Herzegovina     1
# Name: count, Length: 82, dtype: int64[_]
# Total Number of matches played bySpainis:home_team
# Brazil                    85
# Argentina                 59
# Italy                     57
# England                   40
# Germany                   40
#                           ..
# Jamaica                    1
# FR Yugoslavia              1
# Angola                     1
# Trinidad and Tobago        1
# Bosnia and Herzegovina     1
# Name: count, Length: 82, dtype: int64[_]
# Total Number of matches played byNetherlandsis:home_team
# Brazil                    85
# Argentina                 59
# Italy                     57
# England                   40
# Germany                   40
#                           ..
# Jamaica                    1
# FR Yugoslavia              1
# Angola                     1
# Trinidad and Tobago        1
# Bosnia and Herzegovina     1
# Name: count, Length: 82, dtype: int64[_]
# Total Number of matches played byUruguayis:home_team
# Brazil                    85
# Argentina                 59
# Italy                     57
# England                   40
# Germany                   40
#                           ..
# Jamaica                    1
# FR Yugoslavia              1
# Angola                     1
# Trinidad and Tobago        1
# Bosnia and Herzegovina     1
# Name: count, Length: 82, dtype: int64[_]
# Total Number of matches played bySwedenis:home_team
# Brazil                    85
# Argentina                 59
# Italy                     57
# England                   40
# Germany                   40
#                           ..
# Jamaica                    1
# FR Yugoslavia              1
# Angola                     1
# Trinidad and Tobago        1
# Bosnia and Herzegovina     1
# Name: count, Length: 82, dtype: int64[_]
# Total Number of matches played byBelgiumis:home_team
# Brazil                    85
# Argentina                 59
# Italy                     57
# England                   40
# Germany                   40
#                           ..
# Jamaica                    1
# FR Yugoslavia              1
# Angola                     1
# Trinidad and Tobago        1
# Bosnia and Herzegovina     1
# Name: count, Length: 82, dtype: int64[_]
# Total Number of matches played byPortugalis:home_team
# Brazil                    85
# Argentina                 59
# Italy                     57
# England                   40
# Germany                   40
#                           ..
# Jamaica                    1
# FR Yugoslavia              1
# Angola                     1
# Trinidad and Tobago        1
# Bosnia and Herzegovina     1
# Name: count, Length: 82, dtype: int64[_]
# Total Number of matches played byPolandis:home_team
# Brazil                    85
# Argentina                 59
# Italy                     57
# England                   40
# Germany                   40
#                           ..
# Jamaica                    1
# FR Yugoslavia              1
# Angola                     1
# Trinidad and Tobago        1
# Bosnia and Herzegovina     1
# Name: count, Length: 82, dtype: int64[_]
# Total Number of matches played bySoviet Unionis:home_team
# Brazil                    85
# Argentina                 59
# Italy                     57
# England                   40
# Germany                   40
#                           ..
# Jamaica                    1
# FR Yugoslavia              1
# Angola                     1
# Trinidad and Tobago        1
# Bosnia and Herzegovina     1
# Name: count, Length: 82, dtype: int64[_]
# Total Number of matches played byHungaryis:home_team
# Brazil                    85
# Argentina                 59
# Italy                     57
# England                   40
# Germany                   40
#                           ..
# Jamaica                    1
# FR Yugoslavia              1
# Angola                     1
# Trinidad and Tobago        1
# Bosnia and Herzegovina     1
# Name: count, Length: 82, dtype: int64[_]
# Total Number of matches played byMexicois:home_team
# Brazil                    85
# Argentina                 59
# Italy                     57
# England                   40
# Germany                   40
#                           ..
# Jamaica                    1
# FR Yugoslavia              1
# Angola                     1
# Trinidad and Tobago        1
# Bosnia and Herzegovina     1
# Name: count, Length: 82, dtype: int64[_]
# Total Number of matches played byKorea Republicis:home_team
# Brazil                    85
# Argentina                 59
# Italy                     57
# England                   40
# Germany                   40
#                           ..
# Jamaica                    1
# FR Yugoslavia              1
# Angola                     1
# Trinidad and Tobago        1
# Bosnia and Herzegovina     1
# Name: count, Length: 82, dtype: int64[_]
# Total Number of matches played bySwitzerlandis:home_team
# Brazil                    85
# Argentina                 59
# Italy                     57
# England                   40
# Germany                   40
#                           ..
# Jamaica                    1
# FR Yugoslavia              1
# Angola                     1
# Trinidad and Tobago        1
# Bosnia and Herzegovina     1
# Name: count, Length: 82, dtype: int64[_]
# Total Number of matches played byUnited Statesis:home_team
# Brazil                    85
# Argentina                 59
# Italy                     57
# England                   40
# Germany                   40
#                           ..
# Jamaica                    1
# FR Yugoslavia              1
# Angola                     1
# Trinidad and Tobago        1
# Bosnia and Herzegovina     1
# Name: count, Length: 82, dtype: int64[_]
# Total Number of matches played byYugoslaviais:home_team
# Brazil                    85
# Argentina                 59
# Italy                     57
# England                   40
# Germany                   40
#                           ..
# Jamaica                    1
# FR Yugoslavia              1
# Angola                     1
# Trinidad and Tobago        1
# Bosnia and Herzegovina     1
# Name: count, Length: 82, dtype: int64[_]
# Total Number of matches played byJapanis:home_team
# Brazil                    85
# Argentina                 59
# Italy                     57
# England                   40
# Germany                   40
#                           ..
# Jamaica                    1
# FR Yugoslavia              1
# Angola                     1
# Trinidad and Tobago        1
# Bosnia and Herzegovina     1
# Name: count, Length: 82, dtype: int64[_]
# Total Number of matches played byChileis:home_team
# Brazil                    85
# Argentina                 59
# Italy                     57
# England                   40
# Germany                   40
#                           ..
# Jamaica                    1
# FR Yugoslavia              1
# Angola                     1
# Trinidad and Tobago        1
# Bosnia and Herzegovina     1
# Name: count, Length: 82, dtype: int64[_]
# Total Number of matches played byCameroonis:home_team
# Brazil                    85
# Argentina                 59
# Italy                     57
# England                   40
# Germany                   40
#                           ..
# Jamaica                    1
# FR Yugoslavia              1
# Angola                     1
# Trinidad and Tobago        1
# Bosnia and Herzegovina     1
# Name: count, Length: 82, dtype: int64[_]
# Total Number of matches played byAustriais:home_team
# Brazil                    85
# Argentina                 59
# Italy                     57
# England                   40
# Germany                   40
#                           ..
# Jamaica                    1
# FR Yugoslavia              1
# Angola                     1
# Trinidad and Tobago        1
# Bosnia and Herzegovina     1
# Name: count, Length: 82, dtype: int64[_]
# Total Number of matches played byParaguayis:home_team
# Brazil                    85
# Argentina                 59
# Italy                     57
# England                   40
# Germany                   40
#                           ..
# Jamaica                    1
# FR Yugoslavia              1
# Angola                     1
# Trinidad and Tobago        1
# Bosnia and Herzegovina     1
# Name: count, Length: 82, dtype: int64[_]
# Total Number of matches played byNigeriais:home_team
# Brazil                    85
# Argentina                 59
# Italy                     57
# England                   40
# Germany                   40
#                           ..
# Jamaica                    1
# FR Yugoslavia              1
# Angola                     1
# Trinidad and Tobago        1
# Bosnia and Herzegovina     1
# Name: count, Length: 82, dtype: int64[_]
# Total Number of matches played byDenmarkis:home_team
# Brazil                    85
# Argentina                 59
# Italy                     57
# England                   40
# Germany                   40
#                           ..
# Jamaica                    1
# FR Yugoslavia              1
# Angola                     1
# Trinidad and Tobago        1
# Bosnia and Herzegovina     1
# Name: count, Length: 82, dtype: int64[_]
# Total Number of matches played byCzechoslovakiais:home_team
# Brazil                    85
# Argentina                 59
# Italy                     57
# England                   40
# Germany                   40
#                           ..
# Jamaica                    1
# FR Yugoslavia              1
# Angola                     1
# Trinidad and Tobago        1
# Bosnia and Herzegovina     1
# Name: count, Length: 82, dtype: int64[_]
# Total Number of matches played byCroatiais:home_team
# Brazil                    85
# Argentina                 59
# Italy                     57
# England                   40
# Germany                   40
#                           ..
# Jamaica                    1
# FR Yugoslavia              1
# Angola                     1
# Trinidad and Tobago        1
# Bosnia and Herzegovina     1
# Name: count, Length: 82, dtype: int64[_]
# Total Number of matches played byScotlandis:home_team
# Brazil                    85
# Argentina                 59
# Italy                     57
# England                   40
# Germany                   40
#                           ..
# Jamaica                    1
# FR Yugoslavia              1
# Angola                     1
# Trinidad and Tobago        1
# Bosnia and Herzegovina     1
# Name: count, Length: 82, dtype: int64[_]
# Total Number of matches played byRomaniais:home_team
# Brazil                    85
# Argentina                 59
# Italy                     57
# England                   40
# Germany                   40
#                           ..
# Jamaica                    1
# FR Yugoslavia              1
# Angola                     1
# Trinidad and Tobago        1
# Bosnia and Herzegovina     1
# Name: count, Length: 82, dtype: int64[_]
# Total Number of matches played byColombiais:home_team
# Brazil                    85
# Argentina                 59
# Italy                     57
# England                   40
# Germany                   40
#                           ..
# Jamaica                    1
# FR Yugoslavia              1
# Angola                     1
# Trinidad and Tobago        1
# Bosnia and Herzegovina     1
# Name: count, Length: 82, dtype: int64[_]
# Total Number of matches played byMoroccois:home_team
# Brazil                    85
# Argentina                 59
# Italy                     57
# England                   40
# Germany                   40
#                           ..
# Jamaica                    1
# FR Yugoslavia              1
# Angola                     1
# Trinidad and Tobago        1
# Bosnia and Herzegovina     1
# Name: count, Length: 82, dtype: int64[_]
# Total Number of matches played bySaudi Arabiais:home_team
# Brazil                    85
# Argentina                 59
# Italy                     57
# England                   40
# Germany                   40
#                           ..
# Jamaica                    1
# FR Yugoslavia              1
# Angola                     1
# Trinidad and Tobago        1
# Bosnia and Herzegovina     1
# Name: count, Length: 82, dtype: int64[_]
# Total Number of matches played byAustraliais:home_team
# Brazil                    85
# Argentina                 59
# Italy                     57
# England                   40
# Germany                   40
#                           ..
# Jamaica                    1
# FR Yugoslavia              1
# Angola                     1
# Trinidad and Tobago        1
# Bosnia and Herzegovina     1
# Name: count, Length: 82, dtype: int64[_]
# Total Number of matches played byCosta Ricais:home_team
# Brazil                    85
# Argentina                 59
# Italy                     57
# England                   40
# Germany                   40
#                           ..
# Jamaica                    1
# FR Yugoslavia              1
# Angola                     1
# Trinidad and Tobago        1
# Bosnia and Herzegovina     1
# Name: count, Length: 82, dtype: int64[_]
# Total Number of matches played byTunisiais:home_team
# Brazil                    85
# Argentina                 59
# Italy                     57
# England                   40
# Germany                   40
#                           ..
# Jamaica                    1
# FR Yugoslavia              1
# Angola                     1
# Trinidad and Tobago        1
# Bosnia and Herzegovina     1
# Name: count, Length: 82, dtype: int64[_]
# Total Number of matches played byBulgariais:home_team
# Brazil                    85
# Argentina                 59
# Italy                     57
# England                   40
# Germany                   40
#                           ..
# Jamaica                    1
# FR Yugoslavia              1
# Angola                     1
# Trinidad and Tobago        1
# Bosnia and Herzegovina     1
# Name: count, Length: 82, dtype: int64[_]
# Total Number of matches played byPeruis:home_team
# Brazil                    85
# Argentina                 59
# Italy                     57
# England                   40
# Germany                   40
#                           ..
# Jamaica                    1
# FR Yugoslavia              1
# Angola                     1
# Trinidad and Tobago        1
# Bosnia and Herzegovina     1
# Name: count, Length: 82, dtype: int64[_]
# Total Number of matches played bySouth Africais:home_team
# Brazil                    85
# Argentina                 59
# Italy                     57
# England                   40
# Germany                   40
#                           ..
# Jamaica                    1
# FR Yugoslavia              1
# Angola                     1
# Trinidad and Tobago        1
# Bosnia and Herzegovina     1
# Name: count, Length: 82, dtype: int64[_]
# Total Number of matches played byRussiais:home_team
# Brazil                    85
# Argentina                 59
# Italy                     57
# England                   40
# Germany                   40
#                           ..
# Jamaica                    1
# FR Yugoslavia              1
# Angola                     1
# Trinidad and Tobago        1
# Bosnia and Herzegovina     1
# Name: count, Length: 82, dtype: int64[_]
# Total Number of matches played byAlgeriais:home_team
# Brazil                    85
# Argentina                 59
# Italy                     57
# England                   40
# Germany                   40
#                           ..
# Jamaica                    1
# FR Yugoslavia              1
# Angola                     1
# Trinidad and Tobago        1
# Bosnia and Herzegovina     1
# Name: count, Length: 82, dtype: int64[_]
# Total Number of matches played byEcuadoris:home_team
# Brazil                    85
# Argentina                 59
# Italy                     57
# England                   40
# Germany                   40
#                           ..
# Jamaica                    1
# FR Yugoslavia              1
# Angola                     1
# Trinidad and Tobago        1
# Bosnia and Herzegovina     1
# Name: count, Length: 82, dtype: int64[_]
# Total Number of matches played byIR Iranis:home_team
# Brazil                    85
# Argentina                 59
# Italy                     57
# England                   40
# Germany                   40
#                           ..
# Jamaica                    1
# FR Yugoslavia              1
# Angola                     1
# Trinidad and Tobago        1
# Bosnia and Herzegovina     1
# Name: count, Length: 82, dtype: int64[_]
# Total Number of matches played byGhanais:home_team
# Brazil                    85
# Argentina                 59
# Italy                     57
# England                   40
# Germany                   40
#                           ..
# Jamaica                    1
# FR Yugoslavia              1
# Angola                     1
# Trinidad and Tobago        1
# Bosnia and Herzegovina     1
# Name: count, Length: 82, dtype: int64[_]
# Total Number of matches played byRepublic of Irelandis:home_team
# Brazil                    85
# Argentina                 59
# Italy                     57
# England                   40
# Germany                   40
#                           ..
# Jamaica                    1
# FR Yugoslavia              1
# Angola                     1
# Trinidad and Tobago        1
# Bosnia and Herzegovina     1
# Name: count, Length: 82, dtype: int64[_]
# Total Number of matches played byHondurasis:home_team
# Brazil                    85
# Argentina                 59
# Italy                     57
# England                   40
# Germany                   40
#                           ..
# Jamaica                    1
# FR Yugoslavia              1
# Angola                     1
# Trinidad and Tobago        1
# Bosnia and Herzegovina     1
# Name: count, Length: 82, dtype: int64[_]
# Total Number of matches played byNorthern Irelandis:home_team
# Brazil                    85
# Argentina                 59
# Italy                     57
# England                   40
# Germany                   40
#                           ..
# Jamaica                    1
# FR Yugoslavia              1
# Angola                     1
# Trinidad and Tobago        1
# Bosnia and Herzegovina     1
# Name: count, Length: 82, dtype: int64[_]
# Total Number of matches played bySerbiais:home_team
# Brazil                    85
# Argentina                 59
# Italy                     57
# England                   40
# Germany                   40
#                           ..
# Jamaica                    1
# FR Yugoslavia              1
# Angola                     1
# Trinidad and Tobago        1
# Bosnia and Herzegovina     1
# Name: count, Length: 82, dtype: int64[_]
# Total Number of matches played byGreeceis:home_team
# Brazil                    85
# Argentina                 59
# Italy                     57
# England                   40
# Germany                   40
#                           ..
# Jamaica                    1
# FR Yugoslavia              1
# Angola                     1
# Trinidad and Tobago        1
# Bosnia and Herzegovina     1
# Name: count, Length: 82, dtype: int64[_]
# Total Number of matches played bySenegalis:home_team
# Brazil                    85
# Argentina                 59
# Italy                     57
# England                   40
# Germany                   40
#                           ..
# Jamaica                    1
# FR Yugoslavia              1
# Angola                     1
# Trinidad and Tobago        1
# Bosnia and Herzegovina     1
# Name: count, Length: 82, dtype: int64[_]
# Total Number of matches played byKorea DPRis:home_team
# Brazil                    85
# Argentina                 59
# Italy                     57
# England                   40
# Germany                   40
#                           ..
# Jamaica                    1
# FR Yugoslavia              1
# Angola                     1
# Trinidad and Tobago        1
# Bosnia and Herzegovina     1
# Name: count, Length: 82, dtype: int64[_]
# Total Number of matches played byGermany DRis:home_team
# Brazil                    85
# Argentina                 59
# Italy                     57
# England                   40
# Germany                   40
#                           ..
# Jamaica                    1
# FR Yugoslavia              1
# Angola                     1
# Trinidad and Tobago        1
# Bosnia and Herzegovina     1
# Name: count, Length: 82, dtype: int64[_]
# Total Number of matches played bySloveniais:home_team
# Brazil                    85
# Argentina                 59
# Italy                     57
# England                   40
# Germany                   40
#                           ..
# Jamaica                    1
# FR Yugoslavia              1
# Angola                     1
# Trinidad and Tobago        1
# Bosnia and Herzegovina     1
# Name: count, Length: 82, dtype: int64[_]
# Total Number of matches played byCôte d'Ivoireis:home_team
# Brazil                    85
# Argentina                 59
# Italy                     57
# England                   40
# Germany                   40
#                           ..
# Jamaica                    1
# FR Yugoslavia              1
# Angola                     1
# Trinidad and Tobago        1
# Bosnia and Herzegovina     1
# Name: count, Length: 82, dtype: int64[_]
# Total Number of matches played byWalesis:home_team
# Brazil                    85
# Argentina                 59
# Italy                     57
# England                   40
# Germany                   40
#                           ..
# Jamaica                    1
# FR Yugoslavia              1
# Angola                     1
# Trinidad and Tobago        1
# Bosnia and Herzegovina     1
# Name: count, Length: 82, dtype: int64[_]
# Total Number of matches played byIraqis:home_team
# Brazil                    85
# Argentina                 59
# Italy                     57
# England                   40
# Germany                   40
#                           ..
# Jamaica                    1
# FR Yugoslavia              1
# Angola                     1
# Trinidad and Tobago        1
# Bosnia and Herzegovina     1
# Name: count, Length: 82, dtype: int64[_]
# Total Number of matches played byZaireis:home_team
# Brazil                    85
# Argentina                 59
# Italy                     57
# England                   40
# Germany                   40
#                           ..
# Jamaica                    1
# FR Yugoslavia              1
# Angola                     1
# Trinidad and Tobago        1
# Bosnia and Herzegovina     1
# Name: count, Length: 82, dtype: int64[_]
# Total Number of matches played byCubais:home_team
# Brazil                    85
# Argentina                 59
# Italy                     57
# England                   40
# Germany                   40
#                           ..
# Jamaica                    1
# FR Yugoslavia              1
# Angola                     1
# Trinidad and Tobago        1
# Bosnia and Herzegovina     1
# Name: count, Length: 82, dtype: int64[_]
# Total Number of matches played byCanadais:home_team
# Brazil                    85
# Argentina                 59
# Italy                     57
# England                   40
# Germany                   40
#                           ..
# Jamaica                    1
# FR Yugoslavia              1
# Angola                     1
# Trinidad and Tobago        1
# Bosnia and Herzegovina     1
# Name: count, Length: 82, dtype: int64[_]
# Total Number of matches played byQataris:home_team
# Brazil                    85
# Argentina                 59
# Italy                     57
# England                   40
# Germany                   40
#                           ..
# Jamaica                    1
# FR Yugoslavia              1
# Angola                     1
# Trinidad and Tobago        1
# Bosnia and Herzegovina     1
# Name: count, Length: 82, dtype: int64[_]
# Total Number of matches played bySlovakiais:home_team
# Brazil                    85
# Argentina                 59
# Italy                     57
# England                   40
# Germany                   40
#                           ..
# Jamaica                    1
# FR Yugoslavia              1
# Angola                     1
# Trinidad and Tobago        1
# Bosnia and Herzegovina     1
# Name: count, Length: 82, dtype: int64[_]
# Total Number of matches played byCzech Republicis:home_team
# Brazil                    85
# Argentina                 59
# Italy                     57
# England                   40
# Germany                   40
#                           ..
# Jamaica                    1
# FR Yugoslavia              1
# Angola                     1
# Trinidad and Tobago        1
# Bosnia and Herzegovina     1
# Name: count, Length: 82, dtype: int64[_]
# Total Number of matches played byTogois:home_team
# Brazil                    85
# Argentina                 59
# Italy                     57
# England                   40
# Germany                   40
#                           ..
# Jamaica                    1
# FR Yugoslavia              1
# Angola                     1
# Trinidad and Tobago        1
# Bosnia and Herzegovina     1
# Name: count, Length: 82, dtype: int64[_]
# Total Number of matches played byTürkiyeis:home_team
# Brazil                    85
# Argentina                 59
# Italy                     57
# England                   40
# Germany                   40
#                           ..
# Jamaica                    1
# FR Yugoslavia              1
# Angola                     1
# Trinidad and Tobago        1
# Bosnia and Herzegovina     1
# Name: count, Length: 82, dtype: int64[_]
# Total Number of matches played byChina PRis:home_team
# Brazil                    85
# Argentina                 59
# Italy                     57
# England                   40
# Germany                   40
#                           ..
# Jamaica                    1
# FR Yugoslavia              1
# Angola                     1
# Trinidad and Tobago        1
# Bosnia and Herzegovina     1
# Name: count, Length: 82, dtype: int64[_]
# Total Number of matches played byUnited Arab Emiratesis:home_team
# Brazil                    85
# Argentina                 59
# Italy                     57
# England                   40
# Germany                   40
#                           ..
# Jamaica                    1
# FR Yugoslavia              1
# Angola                     1
# Trinidad and Tobago        1
# Bosnia and Herzegovina     1
# Name: count, Length: 82, dtype: int64[_]
# Total Number of matches played byHaitiis:home_team
# Brazil                    85
# Argentina                 59
# Italy                     57
# England                   40
# Germany                   40
#                           ..
# Jamaica                    1
# FR Yugoslavia              1
# Angola                     1
# Trinidad and Tobago        1
# Bosnia and Herzegovina     1
# Name: count, Length: 82, dtype: int64[_]
# Total Number of matches played byPanamais:home_team
# Brazil                    85
# Argentina                 59
# Italy                     57
# England                   40
# Germany                   40
#                           ..
# Jamaica                    1
# FR Yugoslavia              1
# Angola                     1
# Trinidad and Tobago        1
# Bosnia and Herzegovina     1
# Name: count, Length: 82, dtype: int64[_]
# Total Number of matches played byIcelandis:home_team
# Brazil                    85
# Argentina                 59
# Italy                     57
# England                   40
# Germany                   40
#                           ..
# Jamaica                    1
# FR Yugoslavia              1
# Angola                     1
# Trinidad and Tobago        1
# Bosnia and Herzegovina     1
# Name: count, Length: 82, dtype: int64[_]
# Total Number of matches played byEgyptis:home_team
# Brazil                    85
# Argentina                 59
# Italy                     57
# England                   40
# Germany                   40
#                           ..
# Jamaica                    1
# FR Yugoslavia              1
# Angola                     1
# Trinidad and Tobago        1
# Bosnia and Herzegovina     1
# Name: count, Length: 82, dtype: int64[_]
# Total Number of matches played byUkraineis:home_team
# Brazil                    85
# Argentina                 59
# Italy                     57
# England                   40
# Germany                   40
#                           ..
# Jamaica                    1
# FR Yugoslavia              1
# Angola                     1
# Trinidad and Tobago        1
# Bosnia and Herzegovina     1
# Name: count, Length: 82, dtype: int64[_]
# Total Number of matches played byNew Zealandis:home_team
# Brazil                    85
# Argentina                 59
# Italy                     57
# England                   40
# Germany                   40
#                           ..
# Jamaica                    1
# FR Yugoslavia              1
# Angola                     1
# Trinidad and Tobago        1
# Bosnia and Herzegovina     1
# Name: count, Length: 82, dtype: int64[_]
# Total Number of matches played byNorwayis:home_team
# Brazil                    85
# Argentina                 59
# Italy                     57
# England                   40
# Germany                   40
#                           ..
# Jamaica                    1
# FR Yugoslavia              1
# Angola                     1
# Trinidad and Tobago        1
# Bosnia and Herzegovina     1
# Name: count, Length: 82, dtype: int64[_]
# Total Number of matches played byBoliviais:home_team
# Brazil                    85
# Argentina                 59
# Italy                     57
# England                   40
# Germany                   40
#                           ..
# Jamaica                    1
# FR Yugoslavia              1
# Angola                     1
# Trinidad and Tobago        1
# Bosnia and Herzegovina     1
# Name: count, Length: 82, dtype: int64[_]
# Total Number of matches played bySerbia and Montenegrois:home_team
# Brazil                    85
# Argentina                 59
# Italy                     57
# England                   40
# Germany                   40
#                           ..
# Jamaica                    1
# FR Yugoslavia              1
# Angola                     1
# Trinidad and Tobago        1
# Bosnia and Herzegovina     1
# Name: count, Length: 82, dtype: int64[_]
# Total Number of matches played byJamaicais:home_team
# Brazil                    85
# Argentina                 59
# Italy                     57
# England                   40
# Germany                   40
#                           ..
# Jamaica                    1
# FR Yugoslavia              1
# Angola                     1
# Trinidad and Tobago        1
# Bosnia and Herzegovina     1
# Name: count, Length: 82, dtype: int64[_]
# Total Number of matches played byFR Yugoslaviais:home_team
# Brazil                    85
# Argentina                 59
# Italy                     57
# England                   40
# Germany                   40
#                           ..
# Jamaica                    1
# FR Yugoslavia              1
# Angola                     1
# Trinidad and Tobago        1
# Bosnia and Herzegovina     1
# Name: count, Length: 82, dtype: int64[_]
# Total Number of matches played byAngolais:home_team
# Brazil                    85
# Argentina                 59
# Italy                     57
# England                   40
# Germany                   40
#                           ..
# Jamaica                    1
# FR Yugoslavia              1
# Angola                     1
# Trinidad and Tobago        1
# Bosnia and Herzegovina     1
# Name: count, Length: 82, dtype: int64[_]
# Total Number of matches played byTrinidad and Tobagois:home_team
# Brazil                    85
# Argentina                 59
# Italy                     57
# England                   40
# Germany                   40
#                           ..
# Jamaica                    1
# FR Yugoslavia              1
# Angola                     1
# Trinidad and Tobago        1
# Bosnia and Herzegovina     1
# Name: count, Length: 82, dtype: int64[_]
# Total Number of matches played byBosnia and Herzegovinais:home_team
# Brazil                    85
# Argentina                 59
# Italy                     57
# England                   40
# Germany                   40
#                           ..
# Jamaica                    1
# FR Yugoslavia              1
# Angola                     1
# Trinidad and Tobago        1
# Bosnia and Herzegovina     1
# Name: count, Length: 82, dtype: int64[_]

# %%
# %matplotlib inline

# %%
Town30=df['home_team'].value_counts().values>30

# %%
Town30
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False])

# %%
GraphData={}

# %%
townName=[]
matchesplayed=[]
TownData=df['home_team'].value_counts()
for _ in TownData.index:
  if TownData[_]>30:
    townName.append(_)
    matchesplayed.append(TownData[_])

# %%
townName
# Out:
# ['Brazil',
#  'Argentina',
#  'Italy',
#  'England',
#  'Germany',
#  'France',
#  'West Germany',
#  'Spain',
#  'Netherlands',
#  'Uruguay']

# %%
from matplotlib import pyplot as plt

# %%
plt.bar(townName,matchesplayed)
plt.xlabel('TownName')
plt.ylabel('matchesplayed')
plt.title('matches played by Towns')
plt.show()

# %%
f1=df['home_team'].value_counts()>30

# %%
f1
# Out:
# home_team
# Brazil                     True
# Argentina                  True
# Italy                      True
# England                    True
# Germany                    True
#                           ...
# Jamaica                   False
# FR Yugoslavia             False
# Angola                    False
# Trinidad and Tobago       False
# Bosnia and Herzegovina    False
# Name: count, Length: 82, dtype: bool

# %%
df['home_team'].value_counts()
# Out:
# home_team
# Brazil                    85
# Argentina                 59
# Italy                     57
# England                   40
# Germany                   40
#                           ..
# Jamaica                    1
# FR Yugoslavia              1
# Angola                     1
# Trinidad and Tobago        1
# Bosnia and Herzegovina     1
# Name: count, Length: 82, dtype: int64

# %%
teamsAbove30=df['home_team'].value_counts()>30

# %%
teamsAbove30
# Out:
# home_team
# Brazil                     True
# Argentina                  True
# Italy                      True
# England                    True
# Germany                    True
#                           ...
# Jamaica                   False
# FR Yugoslavia             False
# Angola                    False
# Trinidad and Tobago       False
# Bosnia and Herzegovina    False
# Name: count, Length: 82, dtype: bool

# %%
Above30=df['home_team'].value_counts()

# %%
filteredData=Above30[Above30> 30]

# %%
filteredData.plot(kind='bar')
# Out:
# <Axes: xlabel='home_team'>

# %%
def matchesplayedByTown2():
  Above30=df['home_team'].value_counts()
  filteredData=Above30[Above30> 30]
  filteredData.plot(kind='bar')

# %%
matchesplayedByTown2()

# %%
df['home_team'].value_counts()
# Out:
# home_team
# Brazil                    85
# Argentina                 59
# Italy                     57
# England                   40
# Germany                   40
#                           ..
# Jamaica                    1
# FR Yugoslavia              1
# Angola                     1
# Trinidad and Tobago        1
# Bosnia and Herzegovina     1
# Name: count, Length: 82, dtype: int64

# %%
filteredData=df['home_team'].value_counts()

# %%
f2=filteredData[filteredData>=40].index

# %%
f2
# Out:
# Index(['Brazil', 'Argentina', 'Italy', 'England', 'Germany'], dtype='object', name='home_team')

# %%
df[df["home_team"].isin(f2)]
# Out:
# Empty DataFrame
# Columns: [home_team, away_team, home_score, home_xg, home_penalty, away_score, away_xg, away_penalty, home_manager, home_captain, away_manager, away_captain, Attendance, Venue, Officials, Round, Date, Score, Referee, Notes, Host, Year, home_goal, away_goal, home_goal_long, away_goal_long, home_own_goal, away_own_goal, home_penalty_goal, away_penalty_goal, home_penalty_miss_long, away_penalty_miss_long, home_penalty_shootout_goal_long, away_penalty_shootout_goal_long, home_penalty_shootout_miss_long, away_penalty_shootout_miss_long, home_red_card, away_red_card, home_yellow_red_card, away_yellow_red_card, home_yellow_card_long, away_yellow_card_long, home_substitute_in_long, away_substitute_in_long]
# Index: []
#
# [0 rows x 44 columns]

# %%
df[df["home_xg"].isin(f2)]
# Out:
# Empty DataFrame
# Columns: [home_team, away_team, home_score, home_xg, home_penalty, away_score, away_xg, away_penalty, home_manager, home_captain, away_manager, away_captain, Attendance, Venue, Officials, Round, Date, Score, Referee, Notes, Host, Year, home_goal, away_goal, home_goal_long, away_goal_long, home_own_goal, away_own_goal, home_penalty_goal, away_penalty_goal, home_penalty_miss_long, away_penalty_miss_long, home_penalty_shootout_goal_long, away_penalty_shootout_goal_long, home_penalty_shootout_miss_long, away_penalty_shootout_miss_long, home_red_card, away_red_card, home_yellow_red_card, away_yellow_red_card, home_yellow_card_long, away_yellow_card_long, home_substitute_in_long, away_substitute_in_long]
# Index: []
#
# [0 rows x 44 columns]

# %%
df2=df[df["home_team"].isin(f2)]

# %%
df2
# Out:
#      home_team       away_team  home_score  home_xg  home_penalty  away_score  \
# 0    Argentina          France           3      3.3           4.0           3
# 3    Argentina         Croatia           3      2.3           NaN           0
# 5      England          France           1      2.4           NaN           2
# 11      Brazil  Korea Republic           4      3.6           NaN           1
# 13     England         Senegal           3      1.0           NaN           0
# ..         ...             ...         ...      ...           ...         ...
# 948  Argentina   United States           6      NaN           NaN           1
# 949  Argentina           Chile           3      NaN           NaN           1
# 951     Brazil         Bolivia           4      NaN           NaN           0
# 954  Argentina          Mexico           6      NaN           NaN           3
# 959  Argentina          France           1      NaN           NaN           0
#
#      away_xg  away_penalty         home_manager     home_captain  ...  \
# 0        2.2           2.0       Lionel Scaloni     Lionel Messi  ...
# 3        0.5           NaN       Lionel Scaloni     Lionel Messi  ...
# 5        0.9           NaN     Gareth Southgate       Harry Kane  ...
# 11       0.5           NaN                 Tite     Thiago Silva  ...
# 13       0.8           NaN     Gareth Southgate       Harry Kane  ...
# ..       ...           ...                  ...              ...  ...
# 948      NaN           NaN     Francisco Olazar  Manuel Ferreira  ...
# 949      NaN           NaN     Francisco Olazar  Manuel Ferreira  ...
# 951      NaN           NaN  Pindaro De Carvalho        Preguinho  ...
# 954      NaN           NaN     Francisco Olazar     Ángel Bossio  ...
# 959      NaN           NaN     Francisco Olazar  Manuel Ferreira  ...
#
#     home_penalty_shootout_miss_long  \
# 0                               NaN
# 3                               NaN
# 5                               NaN
# 11                              NaN
# 13                              NaN
# ..                              ...
# 948                             NaN
# 949                             NaN
# 951                             NaN
# 954                             NaN
# 959                             NaN
#
#                        away_penalty_shootout_miss_long  home_red_card  \
# 0    ['3|1:1|Kingsley Coman', '5|2:1|Aurélien Tchou...            NaN
# 3                                                  NaN            NaN
# 5                                                  NaN            NaN
# 11                                                 NaN            NaN
# 13                                                 NaN            NaN
# ..                                                 ...            ...
# 948                                                NaN            NaN
# 949                                                NaN            NaN
# 951                                                NaN            NaN
# 954                                                NaN            NaN
# 959                                                NaN            NaN
#
#     away_red_card home_yellow_red_card away_yellow_red_card  \
# 0             NaN                  NaN                  NaN
# 3             NaN                  NaN                  NaN
# 5             NaN                  NaN                  NaN
# 11            NaN                  NaN                  NaN
# 13            NaN                  NaN                  NaN
# ..            ...                  ...                  ...
# 948           NaN                  NaN                  NaN
# 949           NaN                  NaN                  NaN
# 951           NaN                  NaN                  NaN
# 954           NaN                  NaN                  NaN
# 959           NaN                  NaN                  NaN
#
#                                  home_yellow_card_long  \
# 0    ['45+7&rsquor;|2:0|Enzo Fernández', '90+8&rsqu...
# 3    ['68&rsquor;|2:0|Cristian Romero', '71&rsquor;...
# 5                     ['90&rsquor;|1:2|Harry Maguire']
# 11                                                 NaN
# 13                                                 NaN
# ..                                                 ...
# 948                                                NaN
# 949                                                NaN
# 951                                                NaN
# 954                                                NaN
# 959                                                NaN
#
#                                  away_yellow_card_long  \
# 0    ['55&rsquor;|2:0|Adrien Rabiot', '87&rsquor;|2...
# 3    ['32&rsquor;|0:0|Mateo Kovačić', '32&rsquor;|0...
# 5    ['43&rsquor;|0:1|Antoine Griezmann', '47&rsquo...
# 11                   ['44&rsquor;|4:0|Jung Woo-young']
# 13                ['76&rsquor;|3:0|Kalidou Koulibaly']
# ..                                                 ...
# 948                                                NaN
# 949                                                NaN
# 951                                                NaN
# 954                                                NaN
# 959                                                NaN
#
#                                home_substitute_in_long  \
# 0    ['64&rsquor;|2:0|Marcos Acuña|for Ángel Di Mar...
# 3    ['62&rsquor;|2:0|Lisandro Martínez|for Leandro...
# 5    ['79&rsquor;|1:2|Raheem Sterling|for Bukayo Sa...
# 11   ['63&rsquor;|4:0|Dani Alves|for Éder Militão',...
# 13   ['65&rsquor;|3:0|Jack Grealish|for Phil Foden'...
# ..                                                 ...
# 948                                                NaN
# 949                                                NaN
# 951                                                NaN
# 954                                                NaN
# 959                                                NaN
#
#                                away_substitute_in_long
# 0    ['41&rsquor;|2:0|Randal Kolo Muani|for Ousmane...
# 3    ['46&rsquor;|2:0|Mislav Oršić|for Borna Sosa',...
# 5    ['79&rsquor;|1:2|Kingsley Coman|for Ousmane De...
# 11   ['46&rsquor;|4:0|Hong Chul|for Kim Jin-su', '4...
# 13   ['46&rsquor;|2:0|Pape Matar Sarr|for Krépin Di...
# ..                                                 ...
# 948                                                NaN
# 949                                                NaN
# 951                                                NaN
# 954                                                NaN
# 959                                                NaN
#
# [281 rows x 44 columns]

# %%
df2["home_xg"].value_counts()
# Out:
# home_xg
# 2.2    2
# 2.4    2
# 1.0    2
# 1.4    2
# 2.8    2
# 2.1    1
# 1.3    1
# 2.6    1
# 0.9    1
# 2.7    1
# 3.3    1
# 2.3    1
# 3.1    1
# 0.8    1
# 0.3    1
# 1.6    1
# 3.6    1
# 1.9    1
# Name: count, dtype: int64

# %%
# %matplotlib inline

# %%
df2.plot(x='home_team',y='home_xg',kind='barh')
# Out:
# <Axes: ylabel='home_team'>

# %%
f3=df2["home_xg"]>2.5

# %%
df3=df2[f3]

# %%
df3
# Out:
#      home_team       away_team  home_score  home_xg  home_penalty  away_score  \
# 0    Argentina          France           3      3.3           4.0           3
# 11      Brazil  Korea Republic           4      3.6           NaN           1
# 53     Germany           Japan           1      3.1           NaN           2
# 71      Brazil         Belgium           1      2.8           NaN           2
# 74      Brazil          Mexico           2      2.7           NaN           0
# 96     England          Panama           6      2.8           NaN           1
# 102     Brazil      Costa Rica           2      2.6           NaN           0
#
#      away_xg  away_penalty      home_manager  home_captain  ...  \
# 0        2.2           2.0    Lionel Scaloni  Lionel Messi  ...
# 11       0.5           NaN              Tite  Thiago Silva  ...
# 53       1.5           NaN       Hansi Flick  Manuel Neuer  ...
# 71       0.5           NaN              Tite       Miranda  ...
# 74       0.7           NaN              Tite  Thiago Silva  ...
# 96       1.1           NaN  Gareth Southgate    Harry Kane  ...
# 102      0.1           NaN              Tite  Thiago Silva  ...
#
#     home_penalty_shootout_miss_long  \
# 0                               NaN
# 11                              NaN
# 53                              NaN
# 71                              NaN
# 74                              NaN
# 96                              NaN
# 102                             NaN
#
#                        away_penalty_shootout_miss_long  home_red_card  \
# 0    ['3|1:1|Kingsley Coman', '5|2:1|Aurélien Tchou...            NaN
# 11                                                 NaN            NaN
# 53                                                 NaN            NaN
# 71                                                 NaN            NaN
# 74                                                 NaN            NaN
# 96                                                 NaN            NaN
# 102                                                NaN            NaN
#
#     away_red_card home_yellow_red_card away_yellow_red_card  \
# 0             NaN                  NaN                  NaN
# 11            NaN                  NaN                  NaN
# 53            NaN                  NaN                  NaN
# 71            NaN                  NaN                  NaN
# 74            NaN                  NaN                  NaN
# 96            NaN                  NaN                  NaN
# 102           NaN                  NaN                  NaN
#
#                                  home_yellow_card_long  \
# 0    ['45+7&rsquor;|2:0|Enzo Fernández', '90+8&rsqu...
# 11                                                 NaN
# 53                                                 NaN
# 71   ['85&rsquor;|1:2|Fernandinho', '90&rsquor;|1:2...
# 74   ['43&rsquor;|0:0|Filipe Luís', '59&rsquor;|1:0...
# 96               ['23&rsquor;|2:0|Ruben Loftus-Cheek']
# 102  ['81&rsquor;|0:0|Philippe Coutinho', '81&rsquo...
#
#                                  away_yellow_card_long  \
# 0    ['55&rsquor;|2:0|Adrien Rabiot', '87&rsquor;|2...
# 11                   ['44&rsquor;|4:0|Jung Woo-young']
# 53                                                 NaN
# 71   ['47&rsquor;|0:2|Toby Alderweireld', '71&rsquo...
# 74   ['38&rsquor;|0:0|Edson Álvarez', '55&rsquor;|1...
# 96   ['10&rsquor;|1:0|Armando Cooper', '44&rsquor;|...
# 102                   ['84&rsquor;|0:0|Johnny Acosta']
#
#                                home_substitute_in_long  \
# 0    ['64&rsquor;|2:0|Marcos Acuña|for Ángel Di Mar...
# 11   ['63&rsquor;|4:0|Dani Alves|for Éder Militão',...
# 53   ['67&rsquor;|1:0|Jonas Hofmann|for Thomas Müll...
# 71   ['46&rsquor;|0:2|Roberto Firmino|for Willian',...
# 74   ['80&rsquor;|1:0|Fernandinho|for Paulinho', '8...
# 96   ['63&rsquor;|6:0|Jamie Vardy|for Harry Kane', ...
# 102  ['46&rsquor;|0:0|Douglas Costa|for Willian', '...
#
#                                away_substitute_in_long
# 0    ['41&rsquor;|2:0|Randal Kolo Muani|for Ousmane...
# 11   ['46&rsquor;|4:0|Hong Chul|for Kim Jin-su', '4...
# 53   ['46&rsquor;|1:0|Takehiro Tomiyasu|for Takefus...
# 71   ['83&rsquor;|1:2|Thomas Vermaelen|for Nacer Ch...
# 74   ['46&rsquor;|0:0|Miguel Layún|for Rafael Márqu...
# 96   ['62&rsquor;|5:0|Ricardo Ávila|for Aníbal Godo...
# 102  ['54&rsquor;|0:0|Christian Bolaños|for Marco U...
#
# [7 rows x 44 columns]

# %%
from matplotlib import pyplot as plt

# %%
df3.plot(x="home_team",y="home_xg",kind="bar")
plt.xlabel("Home-team")
plt.ylabel("Home-XG")
plt.title("Home Teams estimated goals")
plt.show()

# %%
df3
# Out:
#      home_team       away_team  home_score  home_xg  home_penalty  away_score  \
# 0    Argentina          France           3      3.3           4.0           3
# 11      Brazil  Korea Republic           4      3.6           NaN           1
# 53     Germany           Japan           1      3.1           NaN           2
# 71      Brazil         Belgium           1      2.8           NaN           2
# 74      Brazil          Mexico           2      2.7           NaN           0
# 96     England          Panama           6      2.8           NaN           1
# 102     Brazil      Costa Rica           2      2.6           NaN           0
#
#      away_xg  away_penalty      home_manager  home_captain  ...  \
# 0        2.2           2.0    Lionel Scaloni  Lionel Messi  ...
# 11       0.5           NaN              Tite  Thiago Silva  ...
# 53       1.5           NaN       Hansi Flick  Manuel Neuer  ...
# 71       0.5           NaN              Tite       Miranda  ...
# 74       0.7           NaN              Tite  Thiago Silva  ...
# 96       1.1           NaN  Gareth Southgate    Harry Kane  ...
# 102      0.1           NaN              Tite  Thiago Silva  ...
#
#     home_penalty_shootout_miss_long  \
# 0                               NaN
# 11                              NaN
# 53                              NaN
# 71                              NaN
# 74                              NaN
# 96                              NaN
# 102                             NaN
#
#                        away_penalty_shootout_miss_long  home_red_card  \
# 0    ['3|1:1|Kingsley Coman', '5|2:1|Aurélien Tchou...            NaN
# 11                                                 NaN            NaN
# 53                                                 NaN            NaN
# 71                                                 NaN            NaN
# 74                                                 NaN            NaN
# 96                                                 NaN            NaN
# 102                                                NaN            NaN
#
#     away_red_card home_yellow_red_card away_yellow_red_card  \
# 0             NaN                  NaN                  NaN
# 11            NaN                  NaN                  NaN
# 53            NaN                  NaN                  NaN
# 71            NaN                  NaN                  NaN
# 74            NaN                  NaN                  NaN
# 96            NaN                  NaN                  NaN
# 102           NaN                  NaN                  NaN
#
#                                  home_yellow_card_long  \
# 0    ['45+7&rsquor;|2:0|Enzo Fernández', '90+8&rsqu...
# 11                                                 NaN
# 53                                                 NaN
# 71   ['85&rsquor;|1:2|Fernandinho', '90&rsquor;|1:2...
# 74   ['43&rsquor;|0:0|Filipe Luís', '59&rsquor;|1:0...
# 96               ['23&rsquor;|2:0|Ruben Loftus-Cheek']
# 102  ['81&rsquor;|0:0|Philippe Coutinho', '81&rsquo...
#
#                                  away_yellow_card_long  \
# 0    ['55&rsquor;|2:0|Adrien Rabiot', '87&rsquor;|2...
# 11                   ['44&rsquor;|4:0|Jung Woo-young']
# 53                                                 NaN
# 71   ['47&rsquor;|0:2|Toby Alderweireld', '71&rsquo...
# 74   ['38&rsquor;|0:0|Edson Álvarez', '55&rsquor;|1...
# 96   ['10&rsquor;|1:0|Armando Cooper', '44&rsquor;|...
# 102                   ['84&rsquor;|0:0|Johnny Acosta']
#
#                                home_substitute_in_long  \
# 0    ['64&rsquor;|2:0|Marcos Acuña|for Ángel Di Mar...
# 11   ['63&rsquor;|4:0|Dani Alves|for Éder Militão',...
# 53   ['67&rsquor;|1:0|Jonas Hofmann|for Thomas Müll...
# 71   ['46&rsquor;|0:2|Roberto Firmino|for Willian',...
# 74   ['80&rsquor;|1:0|Fernandinho|for Paulinho', '8...
# 96   ['63&rsquor;|6:0|Jamie Vardy|for Harry Kane', ...
# 102  ['46&rsquor;|0:0|Douglas Costa|for Willian', '...
#
#                                away_substitute_in_long
# 0    ['41&rsquor;|2:0|Randal Kolo Muani|for Ousmane...
# 11   ['46&rsquor;|4:0|Hong Chul|for Kim Jin-su', '4...
# 53   ['46&rsquor;|1:0|Takehiro Tomiyasu|for Takefus...
# 71   ['83&rsquor;|1:2|Thomas Vermaelen|for Nacer Ch...
# 74   ['46&rsquor;|0:0|Miguel Layún|for Rafael Márqu...
# 96   ['62&rsquor;|5:0|Ricardo Ávila|for Aníbal Godo...
# 102  ['54&rsquor;|0:0|Christian Bolaños|for Marco U...
#
# [7 rows x 44 columns]

# %%
df3.plot(x="home_team",y=['home_score','home_xg'],kind="bar",color=["green","red"])
plt.xlabel("Home-team")
plt.ylabel("Home-XG")
plt.title("Home Teams estimated goals")
plt.show()

# %%
#groupby
df4=df.groupby("home_team")

# %%
type(df4)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
df.groupby("home_team")["home_score"].mean()
# Out:
# home_team
# Algeria         0.833333
# Angola          0.000000
# Argentina       2.050847
# Australia       1.000000
# Austria         2.000000
#                   ...
# Uruguay         2.060606
# Wales           0.666667
# West Germany    2.026316
# Yugoslavia      2.562500
# Zaire           0.000000
# Name: home_score, Length: 82, dtype: float64

# %%
dg=df.groupby("home_team")["home_xg"]

# %%
print(dg.mean())
# Out:
# home_team
# Algeria              NaN
# Angola               NaN
# Argentina       1.842857
# Australia       0.750000
# Austria              NaN
#                   ...
# Uruguay         1.240000
# Wales           0.600000
# West Germany         NaN
# Yugoslavia           NaN
# Zaire                NaN
# Name: home_xg, Length: 82, dtype: float64

# %%
df.describe()
# Out:
#        home_score     home_xg  home_penalty  away_score     away_xg  \
# count  964.000000  128.000000     35.000000  964.000000  128.000000
# mean     1.776971    1.435938      3.285714    1.044606    1.192187
# std      1.596676    0.860391      1.226459    1.071233    0.809258
# min      0.000000    0.100000      0.000000    0.000000    0.000000
# 25%      1.000000    0.800000      3.000000    0.000000    0.600000
# 50%      1.000000    1.300000      3.000000    1.000000    1.000000
# 75%      3.000000    1.925000      4.000000    2.000000    1.525000
# max     10.000000    5.200000      5.000000    7.000000    5.700000
#
#        away_penalty     Attendance         Year
# count     35.000000     964.000000   964.000000
# mean       3.057143   45693.374481  1989.244813
# std        1.136115   22704.131689    24.014409
# min        0.000000    2000.000000  1930.000000
# 25%        2.000000   31800.000000  1974.000000
# 50%        3.000000   42725.000000  1994.000000
# 75%        4.000000   60984.500000  2010.000000
# max        5.000000  173850.000000  2022.000000

# %%
das=pd.DataFrame({
    'Branch':['CSE','ECE','CSE','BBA','BBA'],
    'Name':['virat','suresh','prasad','priya','leela'],
    'Salary':[10000,20000,15000,15000,13000]

})

# %%
das
# Out:
#   Branch    Name  Salary
# 0    CSE   virat   10000
# 1    ECE  suresh   20000
# 2    CSE  prasad   15000
# 3    BBA   priya   15000
# 4    BBA   leela   13000

# %%
sv=das.groupby('Branch')['Salary']

# %%
das.describe()
# Out:
#              Salary
# count      5.000000
# mean   14600.000000
# std     3646.916506
# min    10000.000000
# 25%    13000.000000
# 50%    15000.000000
# 75%    15000.000000
# max    20000.000000

# %%
print(sv)
# Out:
# <pandas.core.groupby.generic.SeriesGroupBy object at 0x7a71e7e0c0d0>

# %%
sv.mean()
# Out:
# Branch
# BBA    14000.0
# CSE    12500.0
# ECE    20000.0
# Name: Salary, dtype: float64

# %%
sv.agg(['mean','min'])
# Out:
#            mean    min
# Branch
# BBA     14000.0  13000
# CSE     12500.0  10000
# ECE     20000.0  20000

# %%
sv2=das.groupby(['Branch','Name'])['Salary']

# %%
sv2.max()
# Out:
# Branch  Name
# BBA     leela     13000
#         priya     15000
# CSE     prasad    15000
#         virat     10000
# ECE     suresh    20000
# Name: Salary, dtype: int64

# %%
import random

# %%
age=[]
weight=[]
height=[]

# %%
df
# Out:
#          home_team away_team  home_score  home_xg  home_penalty  away_score  \
# 0        Argentina    France           3      3.3           4.0           3
# 1          Croatia   Morocco           2      0.7           NaN           1
# 2           France   Morocco           2      2.0           NaN           0
# 3        Argentina   Croatia           3      2.3           NaN           0
# 4          Morocco  Portugal           1      1.4           NaN           0
# ..             ...       ...         ...      ...           ...         ...
# 959      Argentina    France           1      NaN           NaN           0
# 960     Yugoslavia    Brazil           2      NaN           NaN           1
# 961        Romania      Peru           3      NaN           NaN           1
# 962  United States   Belgium           3      NaN           NaN           0
# 963         France    Mexico           4      NaN           NaN           1
#
#      away_xg  away_penalty      home_manager          home_captain  ...  \
# 0        2.2           2.0    Lionel Scaloni          Lionel Messi  ...
# 1        1.2           NaN      Zlatko Dalić           Luka Modrić  ...
# 2        0.9           NaN  Didier Deschamps           Hugo Lloris  ...
# 3        0.5           NaN    Lionel Scaloni          Lionel Messi  ...
# 4        0.9           NaN   Hoalid Regragui          Romain Saïss  ...
# ..       ...           ...               ...                   ...  ...
# 959      NaN           NaN  Francisco Olazar       Manuel Ferreira  ...
# 960      NaN           NaN   Bosko Simonovic       Milutin Ivković  ...
# 961      NaN           NaN     Octav Luchide          Emerich Vogl  ...
# 962      NaN           NaN        Bob Millar            Tom Florie  ...
# 963      NaN           NaN     Raoul Caudron  Alexandre Villaplane  ...
#
#     home_penalty_shootout_miss_long  \
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3                               NaN
# 4                               NaN
# ..                              ...
# 959                             NaN
# 960                             NaN
# 961                             NaN
# 962                             NaN
# 963                             NaN
#
#                        away_penalty_shootout_miss_long  home_red_card  \
# 0    ['3|1:1|Kingsley Coman', '5|2:1|Aurélien Tchou...            NaN
# 1                                                  NaN            NaN
# 2                                                  NaN            NaN
# 3                                                  NaN            NaN
# 4                                                  NaN            NaN
# ..                                                 ...            ...
# 959                                                NaN            NaN
# 960                                                NaN            NaN
# 961                                                NaN            NaN
# 962                                                NaN            NaN
# 963                                                NaN            NaN
#
#             away_red_card   home_yellow_red_card away_yellow_red_card  \
# 0                     NaN                    NaN                  NaN
# 1                     NaN                    NaN                  NaN
# 2                     NaN                    NaN                  NaN
# 3                     NaN                    NaN                  NaN
# 4                     NaN  Walid Cheddira · 90+3                  NaN
# ..                    ...                    ...                  ...
# 959                   NaN                    NaN                  NaN
# 960                   NaN                    NaN                  NaN
# 961  Plácido Galindo · 70                    NaN                  NaN
# 962                   NaN                    NaN                  NaN
# 963                   NaN                    NaN                  NaN
#
#                                  home_yellow_card_long  \
# 0    ['45+7&rsquor;|2:0|Enzo Fernández', '90+8&rsqu...
# 1                                                  NaN
# 2                                                  NaN
# 3    ['68&rsquor;|2:0|Cristian Romero', '71&rsquor;...
# 4    ['70&rsquor;|1:0|Achraf Dari', '90+1&rsquor;|1...
# ..                                                 ...
# 959                                                NaN
# 960                                                NaN
# 961                                                NaN
# 962                                                NaN
# 963                                                NaN
#
#                                  away_yellow_card_long  \
# 0    ['55&rsquor;|2:0|Adrien Rabiot', '87&rsquor;|2...
# 1    ['69&rsquor;|2:1|Azzedine Ounahi', '84&rsquor;...
# 2                    ['27&rsquor;|1:0|Sofiane Boufal']
# 3    ['32&rsquor;|0:0|Mateo Kovačić', '32&rsquor;|0...
# 4                           ['87&rsquor;|1:0|Vitinha']
# ..                                                 ...
# 959                                                NaN
# 960                                                NaN
# 961                                                NaN
# 962                                                NaN
# 963                                                NaN
#
#                                home_substitute_in_long  \
# 0    ['64&rsquor;|2:0|Marcos Acuña|for Ángel Di Mar...
# 1    ['61&rsquor;|2:1|Nikola Vlašić|for Andrej Kram...
# 2    ['65&rsquor;|1:0|Marcus Thuram|for Olivier Gir...
# 3    ['62&rsquor;|2:0|Lisandro Martínez|for Leandro...
# 4    ['57&rsquor;|1:0|Achraf Dari|for Romain Saïss'...
# ..                                                 ...
# 959                                                NaN
# 960                                                NaN
# 961                                                NaN
# 962                                                NaN
# 963                                                NaN
#
#                                away_substitute_in_long
# 0    ['41&rsquor;|2:0|Randal Kolo Muani|for Ousmane...
# 1    ['46&rsquor;|2:1|Ilias Chair|for Abdelhamid Sa...
# 2    ['21&rsquor;|1:0|Selim Amallah|for Romain Saïs...
# 3    ['46&rsquor;|2:0|Mislav Oršić|for Borna Sosa',...
# 4    ['51&rsquor;|1:0|João Cancelo|for Raphaël Guer...
# ..                                                 ...
# 959                                                NaN
# 960                                                NaN
# 961                                                NaN
# 962                                                NaN
# 963                                                NaN
#
# [964 rows x 44 columns]

# %%
df.shape
# Out:
# (964, 44)

# %%
#Loop comprehension
[age.append(random.randint(18,40)) for _ in range(964)]
print(f"Age is now having {len(age)}")
# Out:
# Age is now having 964

# %%
age
# Out:
# [25,
#  25,
#  25,
#  36,
#  28,
#  26,
#  25,
#  22,
#  22,
#  27,
#  35,
#  38,
#  31,
#  26,
#  31,
#  36,
#  21,
#  39,
#  23,
#  19,
#  24,
#  40,
#  27,
#  19,
#  24,
#  26,
#  27,
#  31,
#  21,
#  32,
#  29,
#  39,
#  22,
#  30,
#  32,
#  25,
#  28,
#  34,
#  30,
#  24,
#  27,
#  22,
#  37,
#  24,
#  18,
#  21,
#  31,
#  19,
#  36,
#  18,
#  40,
#  38,
#  21,
#  22,
#  29,
#  29,
#  22,
#  28,
#  32,
#  36,
#  40,
#  24,
#  29,
#  28,
#  38,
#  21,
#  18,
#  22,
#  35,
#  21,
#  25,
#  21,
#  31,
#  28,
#  36,
#  20,
#  18,
#  35,
#  19,
#  31,
#  18,
#  21,
#  27,
#  21,
#  27,
#  34,
#  28,
#  26,
#  20,
#  39,
#  28,
#  31,
#  36,
#  19,
#  18,
#  26,
#  26,
#  35,
#  38,
#  38,
#  36,
#  24,
#  25,
#  35,
#  38,
#  23,
#  33,
#  35,
#  35,
#  29,
#  31,
#  25,
#  26,
#  18,
#  35,
#  25,
#  29,
#  38,
#  39,
#  29,
#  19,
#  37,
#  26,
#  29,
#  40,
#  31,
#  37,
#  25,
#  21,
#  36,
#  35,
#  19,
#  40,
#  24,
#  20,
#  35,
#  38,
#  26,
#  31,
#  27,
#  37,
#  34,
#  39,
#  25,
#  19,
#  32,
#  36,
#  21,
#  29,
#  33,
#  32,
#  29,
#  25,
#  30,
#  21,
#  22,
#  29,
#  37,
#  18,
#  35,
#  36,
#  18,
#  31,
#  33,
#  27,
#  25,
#  37,
#  30,
#  33,
#  27,
#  27,
#  19,
#  25,
#  20,
#  32,
#  36,
#  35,
#  28,
#  39,
#  29,
#  23,
#  39,
#  25,
#  18,
#  36,
#  20,
#  24,
#  27,
#  40,
#  38,
#  26,
#  21,
#  30,
#  26,
#  37,
#  20,
#  37,
#  32,
#  36,
#  32,
#  35,
#  18,
#  32,
#  31,
#  40,
#  20,
#  38,
#  39,
#  26,
#  35,
#  18,
#  40,
#  21,
#  28,
#  25,
#  31,
#  35,
#  39,
#  23,
#  30,
#  30,
#  21,
#  30,
#  23,
#  32,
#  21,
#  25,
#  32,
#  21,
#  37,
#  18,
#  28,
#  23,
#  39,
#  21,
#  26,
#  22,
#  20,
#  30,
#  39,
#  31,
#  19,
#  40,
#  28,
#  35,
#  29,
#  26,
#  28,
#  24,
#  24,
#  37,
#  22,
#  40,
#  34,
#  39,
#  27,
#  28,
#  39,
#  36,
#  39,
#  31,
#  25,
#  33,
#  21,
#  30,
#  35,
#  21,
#  23,
#  26,
#  19,
#  29,
#  24,
#  22,
#  35,
#  27,
#  31,
#  21,
#  26,
#  25,
#  20,
#  29,
#  28,
#  40,
#  21,
#  36,
#  24,
#  19,
#  38,
#  21,
#  32,
#  28,
#  21,
#  27,
#  36,
#  32,
#  34,
#  29,
#  20,
#  30,
#  19,
#  28,
#  20,
#  29,
#  38,
#  39,
#  20,
#  37,
#  30,
#  21,
#  37,
#  32,
#  39,
#  34,
#  39,
#  31,
#  23,
#  31,
#  33,
#  40,
#  23,
#  27,
#  32,
#  35,
#  38,
#  21,
#  29,
#  21,
#  26,
#  24,
#  21,
#  32,
#  34,
#  34,
#  36,
#  38,
#  29,
#  24,
#  20,
#  23,
#  34,
#  37,
#  20,
#  18,
#  24,
#  30,
#  31,
#  19,
#  34,
#  38,
#  30,
#  26,
#  32,
#  32,
#  29,
#  29,
#  27,
#  30,
#  29,
#  38,
#  27,
#  24,
#  38,
#  39,
#  31,
#  29,
#  29,
#  20,
#  35,
#  35,
#  37,
#  24,
#  23,
#  19,
#  26,
#  20,
#  32,
#  29,
#  37,
#  18,
#  22,
#  39,
#  29,
#  30,
#  22,
#  28,
#  27,
#  34,
#  38,
#  20,
#  18,
#  29,
#  22,
#  26,
#  19,
#  39,
#  40,
#  35,
#  18,
#  32,
#  33,
#  31,
#  21,
#  34,
#  23,
#  29,
#  28,
#  18,
#  18,
#  22,
#  21,
#  34,
#  23,
#  23,
#  19,
#  30,
#  29,
#  31,
#  19,
#  25,
#  34,
#  21,
#  31,
#  39,
#  38,
#  31,
#  20,
#  27,
#  25,
#  36,
#  30,
#  19,
#  20,
#  23,
#  23,
#  18,
#  34,
#  36,
#  34,
#  24,
#  29,
#  39,
#  19,
#  19,
#  27,
#  21,
#  33,
#  32,
#  35,
#  26,
#  29,
#  32,
#  26,
#  25,
#  35,
#  25,
#  36,
#  33,
#  28,
#  40,
#  24,
#  20,
#  21,
#  22,
#  24,
#  37,
#  22,
#  18,
#  32,
#  28,
#  26,
#  37,
#  26,
#  36,
#  28,
#  36,
#  23,
#  23,
#  31,
#  20,
#  25,
#  33,
#  20,
#  25,
#  39,
#  35,
#  28,
#  40,
#  20,
#  40,
#  25,
#  21,
#  29,
#  33,
#  36,
#  36,
#  25,
#  28,
#  32,
#  30,
#  25,
#  22,
#  37,
#  36,
#  19,
#  30,
#  22,
#  37,
#  40,
#  30,
#  38,
#  38,
#  34,
#  29,
#  25,
#  34,
#  39,
#  19,
#  19,
#  19,
#  26,
#  31,
#  27,
#  19,
#  25,
#  22,
#  40,
#  27,
#  22,
#  25,
#  33,
#  34,
#  36,
#  28,
#  40,
#  35,
#  27,
#  25,
#  30,
#  34,
#  31,
#  18,
#  33,
#  24,
#  35,
#  36,
#  25,
#  36,
#  19,
#  21,
#  38,
#  21,
#  23,
#  38,
#  23,
#  40,
#  21,
#  21,
#  32,
#  31,
#  38,
#  20,
#  30,
#  30,
#  38,
#  40,
#  22,
#  38,
#  21,
#  26,
#  22,
#  27,
#  22,
#  26,
#  34,
#  39,
#  33,
#  30,
#  38,
#  19,
#  37,
#  29,
#  19,
#  18,
#  18,
#  23,
#  25,
#  40,
#  20,
#  19,
#  21,
#  20,
#  22,
#  21,
#  39,
#  28,
#  36,
#  38,
#  22,
#  27,
#  30,
#  32,
#  19,
#  19,
#  24,
#  34,
#  19,
#  23,
#  18,
#  36,
#  21,
#  18,
#  21,
#  35,
#  40,
#  40,
#  24,
#  36,
#  32,
#  39,
#  33,
#  21,
#  34,
#  25,
#  20,
#  19,
#  21,
#  31,
#  37,
#  33,
#  39,
#  28,
#  23,
#  19,
#  34,
#  30,
#  31,
#  28,
#  36,
#  40,
#  26,
#  34,
#  22,
#  22,
#  26,
#  27,
#  28,
#  32,
#  18,
#  20,
#  20,
#  36,
#  23,
#  25,
#  26,
#  33,
#  38,
#  39,
#  24,
#  29,
#  26,
#  24,
#  28,
#  21,
#  37,
#  29,
#  23,
#  29,
#  21,
#  28,
#  23,
#  23,
#  33,
#  26,
#  29,
#  32,
#  20,
#  37,
#  21,
#  33,
#  40,
#  20,
#  20,
#  19,
#  36,
#  20,
#  23,
#  22,
#  38,
#  19,
#  29,
#  37,
#  25,
#  37,
#  23,
#  31,
#  24,
#  19,
#  21,
#  19,
#  25,
#  37,
#  24,
#  30,
#  28,
#  23,
#  25,
#  19,
#  30,
#  21,
#  19,
#  25,
#  31,
#  27,
#  40,
#  40,
#  25,
#  21,
#  40,
#  38,
#  30,
#  27,
#  25,
#  29,
#  33,
#  34,
#  30,
#  39,
#  38,
#  29,
#  25,
#  28,
#  29,
#  38,
#  18,
#  26,
#  34,
#  34,
#  39,
#  22,
#  25,
#  39,
#  29,
#  38,
#  26,
#  26,
#  19,
#  25,
#  31,
#  38,
#  20,
#  29,
#  20,
#  32,
#  32,
#  25,
#  20,
#  33,
#  25,
#  31,
#  31,
#  34,
#  28,
#  31,
#  34,
#  38,
#  39,
#  37,
#  32,
#  33,
#  30,
#  29,
#  18,
#  40,
#  35,
#  40,
#  35,
#  22,
#  29,
#  37,
#  21,
#  18,
#  18,
#  38,
#  21,
#  30,
#  33,
#  22,
#  28,
#  38,
#  28,
#  39,
#  40,
#  33,
#  22,
#  29,
#  20,
#  24,
#  37,
#  23,
#  34,
#  21,
#  26,
#  30,
#  31,
#  40,
#  29,
#  21,
#  22,
#  39,
#  20,
#  29,
#  25,
#  28,
#  35,
#  31,
#  18,
#  23,
#  21,
#  29,
#  29,
#  25,
#  18,
#  18,
#  30,
#  21,
#  30,
#  29,
#  23,
#  30,
#  39,
#  28,
#  37,
#  19,
#  26,
#  19,
#  35,
#  19,
#  29,
#  28,
#  34,
#  35,
#  25,
#  34,
#  27,
#  20,
#  25,
#  33,
#  29,
#  37,
#  40,
#  38,
#  33,
#  28,
#  34,
#  39,
#  26,
#  34,
#  29,
#  24,
#  24,
#  33,
#  23,
#  39,
#  21,
#  21,
#  32,
#  24,
#  22,
#  38,
#  33,
#  25,
#  31,
#  23,
#  40,
#  31,
#  21,
#  23,
#  24,
#  24,
#  19,
#  29,
#  34,
#  19,
#  25,
#  24,
#  30,
#  18,
#  35,
#  29,
#  24,
#  40,
#  20,
#  20,
#  38,
#  31,
#  34,
#  34,
#  40,
#  19,
#  35,
#  19,
#  26,
#  21,
#  30,
#  21,
#  20,
#  37,
#  29,
#  31,
#  38,
#  20,
#  38,
#  29,
#  22,
#  29,
#  30,
#  19,
#  39,
#  28,
#  37,
#  27,
#  20,
#  27,
#  20,
#  40,
#  19,
#  36,
#  28,
#  39,
#  29,
#  37,
#  37,
#  38,
#  25,
#  21,
#  26,
#  38,
#  31,
#  31,
#  38,
#  39,
#  26,
#  18,
#  28,
#  33,
#  35,
#  36,
#  25,
#  29,
#  34,
#  20,
#  35,
#  24,
#  27,
#  18,
#  26,
#  31,
#  27,
#  27,
#  40,
#  30,
#  19,
#  26,
#  28]

# %%
#Adding a new column to the DFrame
#Syntax:df['NewColumnName']=List/Series of elements

# %%
df['YearsOf Experience']=age

# %%
df
# Out:
#          home_team away_team  home_score  home_xg  home_penalty  away_score  \
# 0        Argentina    France           3      3.3           4.0           3
# 1          Croatia   Morocco           2      0.7           NaN           1
# 2           France   Morocco           2      2.0           NaN           0
# 3        Argentina   Croatia           3      2.3           NaN           0
# 4          Morocco  Portugal           1      1.4           NaN           0
# ..             ...       ...         ...      ...           ...         ...
# 959      Argentina    France           1      NaN           NaN           0
# 960     Yugoslavia    Brazil           2      NaN           NaN           1
# 961        Romania      Peru           3      NaN           NaN           1
# 962  United States   Belgium           3      NaN           NaN           0
# 963         France    Mexico           4      NaN           NaN           1
#
#      away_xg  away_penalty      home_manager          home_captain  ...  \
# 0        2.2           2.0    Lionel Scaloni          Lionel Messi  ...
# 1        1.2           NaN      Zlatko Dalić           Luka Modrić  ...
# 2        0.9           NaN  Didier Deschamps           Hugo Lloris  ...
# 3        0.5           NaN    Lionel Scaloni          Lionel Messi  ...
# 4        0.9           NaN   Hoalid Regragui          Romain Saïss  ...
# ..       ...           ...               ...                   ...  ...
# 959      NaN           NaN  Francisco Olazar       Manuel Ferreira  ...
# 960      NaN           NaN   Bosko Simonovic       Milutin Ivković  ...
# 961      NaN           NaN     Octav Luchide          Emerich Vogl  ...
# 962      NaN           NaN        Bob Millar            Tom Florie  ...
# 963      NaN           NaN     Raoul Caudron  Alexandre Villaplane  ...
#
#                        away_penalty_shootout_miss_long home_red_card  \
# 0    ['3|1:1|Kingsley Coman', '5|2:1|Aurélien Tchou...           NaN
# 1                                                  NaN           NaN
# 2                                                  NaN           NaN
# 3                                                  NaN           NaN
# 4                                                  NaN           NaN
# ..                                                 ...           ...
# 959                                                NaN           NaN
# 960                                                NaN           NaN
# 961                                                NaN           NaN
# 962                                                NaN           NaN
# 963                                                NaN           NaN
#
#             away_red_card   home_yellow_red_card away_yellow_red_card  \
# 0                     NaN                    NaN                  NaN
# 1                     NaN                    NaN                  NaN
# 2                     NaN                    NaN                  NaN
# 3                     NaN                    NaN                  NaN
# 4                     NaN  Walid Cheddira · 90+3                  NaN
# ..                    ...                    ...                  ...
# 959                   NaN                    NaN                  NaN
# 960                   NaN                    NaN                  NaN
# 961  Plácido Galindo · 70                    NaN                  NaN
# 962                   NaN                    NaN                  NaN
# 963                   NaN                    NaN                  NaN
#
#                                  home_yellow_card_long  \
# 0    ['45+7&rsquor;|2:0|Enzo Fernández', '90+8&rsqu...
# 1                                                  NaN
# 2                                                  NaN
# 3    ['68&rsquor;|2:0|Cristian Romero', '71&rsquor;...
# 4    ['70&rsquor;|1:0|Achraf Dari', '90+1&rsquor;|1...
# ..                                                 ...
# 959                                                NaN
# 960                                                NaN
# 961                                                NaN
# 962                                                NaN
# 963                                                NaN
#
#                                  away_yellow_card_long  \
# 0    ['55&rsquor;|2:0|Adrien Rabiot', '87&rsquor;|2...
# 1    ['69&rsquor;|2:1|Azzedine Ounahi', '84&rsquor;...
# 2                    ['27&rsquor;|1:0|Sofiane Boufal']
# 3    ['32&rsquor;|0:0|Mateo Kovačić', '32&rsquor;|0...
# 4                           ['87&rsquor;|1:0|Vitinha']
# ..                                                 ...
# 959                                                NaN
# 960                                                NaN
# 961                                                NaN
# 962                                                NaN
# 963                                                NaN
#
#                                home_substitute_in_long  \
# 0    ['64&rsquor;|2:0|Marcos Acuña|for Ángel Di Mar...
# 1    ['61&rsquor;|2:1|Nikola Vlašić|for Andrej Kram...
# 2    ['65&rsquor;|1:0|Marcus Thuram|for Olivier Gir...
# 3    ['62&rsquor;|2:0|Lisandro Martínez|for Leandro...
# 4    ['57&rsquor;|1:0|Achraf Dari|for Romain Saïss'...
# ..                                                 ...
# 959                                                NaN
# 960                                                NaN
# 961                                                NaN
# 962                                                NaN
# 963                                                NaN
#
#                                away_substitute_in_long YearsOf Experience
# 0    ['41&rsquor;|2:0|Randal Kolo Muani|for Ousmane...                 25
# 1    ['46&rsquor;|2:1|Ilias Chair|for Abdelhamid Sa...                 25
# 2    ['21&rsquor;|1:0|Selim Amallah|for Romain Saïs...                 25
# 3    ['46&rsquor;|2:0|Mislav Oršić|for Borna Sosa',...                 36
# 4    ['51&rsquor;|1:0|João Cancelo|for Raphaël Guer...                 28
# ..                                                 ...                ...
# 959                                                NaN                 40
# 960                                                NaN                 30
# 961                                                NaN                 19
# 962                                                NaN                 26
# 963                                                NaN                 28
#
# [964 rows x 45 columns]

# %%
df['ASP'] = df['YearsOf Experience']-df['home_score']

# %%
df.shape
# Out:
# (964, 46)

# %%
df
# Out:
#          home_team away_team  home_score  home_xg  home_penalty  away_score  \
# 0        Argentina    France           3      3.3           4.0           3
# 1          Croatia   Morocco           2      0.7           NaN           1
# 2           France   Morocco           2      2.0           NaN           0
# 3        Argentina   Croatia           3      2.3           NaN           0
# 4          Morocco  Portugal           1      1.4           NaN           0
# ..             ...       ...         ...      ...           ...         ...
# 959      Argentina    France           1      NaN           NaN           0
# 960     Yugoslavia    Brazil           2      NaN           NaN           1
# 961        Romania      Peru           3      NaN           NaN           1
# 962  United States   Belgium           3      NaN           NaN           0
# 963         France    Mexico           4      NaN           NaN           1
#
#      away_xg  away_penalty      home_manager          home_captain  ...  \
# 0        2.2           2.0    Lionel Scaloni          Lionel Messi  ...
# 1        1.2           NaN      Zlatko Dalić           Luka Modrić  ...
# 2        0.9           NaN  Didier Deschamps           Hugo Lloris  ...
# 3        0.5           NaN    Lionel Scaloni          Lionel Messi  ...
# 4        0.9           NaN   Hoalid Regragui          Romain Saïss  ...
# ..       ...           ...               ...                   ...  ...
# 959      NaN           NaN  Francisco Olazar       Manuel Ferreira  ...
# 960      NaN           NaN   Bosko Simonovic       Milutin Ivković  ...
# 961      NaN           NaN     Octav Luchide          Emerich Vogl  ...
# 962      NaN           NaN        Bob Millar            Tom Florie  ...
# 963      NaN           NaN     Raoul Caudron  Alexandre Villaplane  ...
#
#     home_red_card         away_red_card   home_yellow_red_card  \
# 0             NaN                   NaN                    NaN
# 1             NaN                   NaN                    NaN
# 2             NaN                   NaN                    NaN
# 3             NaN                   NaN                    NaN
# 4             NaN                   NaN  Walid Cheddira · 90+3
# ..            ...                   ...                    ...
# 959           NaN                   NaN                    NaN
# 960           NaN                   NaN                    NaN
# 961           NaN  Plácido Galindo · 70                    NaN
# 962           NaN                   NaN                    NaN
# 963           NaN                   NaN                    NaN
#
#     away_yellow_red_card                              home_yellow_card_long  \
# 0                    NaN  ['45+7&rsquor;|2:0|Enzo Fernández', '90+8&rsqu...
# 1                    NaN                                                NaN
# 2                    NaN                                                NaN
# 3                    NaN  ['68&rsquor;|2:0|Cristian Romero', '71&rsquor;...
# 4                    NaN  ['70&rsquor;|1:0|Achraf Dari', '90+1&rsquor;|1...
# ..                   ...                                                ...
# 959                  NaN                                                NaN
# 960                  NaN                                                NaN
# 961                  NaN                                                NaN
# 962                  NaN                                                NaN
# 963                  NaN                                                NaN
#
#                                  away_yellow_card_long  \
# 0    ['55&rsquor;|2:0|Adrien Rabiot', '87&rsquor;|2...
# 1    ['69&rsquor;|2:1|Azzedine Ounahi', '84&rsquor;...
# 2                    ['27&rsquor;|1:0|Sofiane Boufal']
# 3    ['32&rsquor;|0:0|Mateo Kovačić', '32&rsquor;|0...
# 4                           ['87&rsquor;|1:0|Vitinha']
# ..                                                 ...
# 959                                                NaN
# 960                                                NaN
# 961                                                NaN
# 962                                                NaN
# 963                                                NaN
#
#                                home_substitute_in_long  \
# 0    ['64&rsquor;|2:0|Marcos Acuña|for Ángel Di Mar...
# 1    ['61&rsquor;|2:1|Nikola Vlašić|for Andrej Kram...
# 2    ['65&rsquor;|1:0|Marcus Thuram|for Olivier Gir...
# 3    ['62&rsquor;|2:0|Lisandro Martínez|for Leandro...
# 4    ['57&rsquor;|1:0|Achraf Dari|for Romain Saïss'...
# ..                                                 ...
# 959                                                NaN
# 960                                                NaN
# 961                                                NaN
# 962                                                NaN
# 963                                                NaN
#
#                                away_substitute_in_long YearsOf Experience ASP
# 0    ['41&rsquor;|2:0|Randal Kolo Muani|for Ousmane...                 25  22
# 1    ['46&rsquor;|2:1|Ilias Chair|for Abdelhamid Sa...                 25  23
# 2    ['21&rsquor;|1:0|Selim Amallah|for Romain Saïs...                 25  23
# 3    ['46&rsquor;|2:0|Mislav Oršić|for Borna Sosa',...                 36  33
# 4    ['51&rsquor;|1:0|João Cancelo|for Raphaël Guer...                 28  27
# ..                                                 ...                ...  ..
# 959                                                NaN                 40  39
# 960                                                NaN                 30  28
# 961                                                NaN                 19  16
# 962                                                NaN                 26  23
# 963                                                NaN                 28  24
#
# [964 rows x 46 columns]

# %%
# %matplotlib inline

# %%
from matplotlib import pyplot as plt

# %%
df.plot ( x='YearsOf Experience',y=['ASP','home_score'],kind='bar',color=['red','blue'])
# Out:
# <Axes: xlabel='YearsOf Experience'>

# %%
#Error:same length-NAN-NOt a Number-dtype-Numpy=0
#function to get a graph
def getGraph(DataFrame,column1,column2):
  from matplotlib import pyplot as plt

  #Check the length of column1 and column2
  if len(DataFrame[column1])==len(DataFrame[column2]):
    df.plot(x=column1,y=column2,kind='bar',color=['Red','Black'])
    print('The graph/plot is successfully created')
  else:

      print('please check the column size once')

# %%
getGraph(df,'home_score','away_score')
# Out:
# The graph/plot is successfully created
