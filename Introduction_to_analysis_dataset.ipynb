# %% [markdown]
# <a href="https://colab.research.google.com/github/Masehanridegreecollege/Python-mini-project-/blob/main/Introduction_to_analysis_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

# %%
a1=[]
a2=[]
a3=[]
a4=[]
a5=[]

# %%
for _ in range(1000):
    a1.append(random.randint(0,100))
    a2.append(random.randint(50,70))
    a3.append(random.randint(10,20))
    a4.append(random.randint(8,10))
    a5.append(random.randint(20,80))

# %%
a1
# Out:
# [9,
#  2,
#  1,
#  99,
#  14,
#  29,
#  99,
#  67,
#  59,
#  31,
#  87,
#  77,
#  86,
#  28,
#  97,
#  88,
#  1,
#  16,
#  53,
#  5,
#  89,
#  58,
#  36,
#  63,
#  89,
#  15,
#  27,
#  72,
#  9,
#  88,
#  35,
#  95,
#  86,
#  3,
#  37,
#  29,
#  77,
#  97,
#  6,
#  1,
#  41,
#  0,
#  24,
#  45,
#  69,
#  84,
#  6,
#  20,
#  3,
#  62,
#  79,
#  9,
#  79,
#  87,
#  49,
#  87,
#  87,
#  51,
#  84,
#  45,
#  31,
#  100,
#  90,
#  34,
#  20,
#  7,
#  17,
#  29,
#  85,
#  54,
#  18,
#  42,
#  30,
#  93,
#  4,
#  46,
#  64,
#  71,
#  31,
#  2,
#  9,
#  100,
#  77,
#  24,
#  66,
#  25,
#  44,
#  76,
#  5,
#  86,
#  32,
#  23,
#  55,
#  8,
#  87,
#  29,
#  12,
#  22,
#  86,
#  66,
#  28,
#  66,
#  8,
#  39,
#  28,
#  62,
#  27,
#  90,
#  92,
#  13,
#  85,
#  44,
#  64,
#  27,
#  36,
#  92,
#  61,
#  45,
#  41,
#  56,
#  1,
#  52,
#  74,
#  32,
#  1,
#  90,
#  63,
#  59,
#  51,
#  83,
#  75,
#  10,
#  68,
#  80,
#  76,
#  36,
#  94,
#  39,
#  73,
#  79,
#  45,
#  8,
#  0,
#  51,
#  62,
#  92,
# ...

# %%
df={
   'grade':a1,
   'weight':a2,
   'friends':a3,
   'cousins':a4,
   'projects':a5
}

# %%
df
# Out:
# {'grade': [9,
#   2,
#   1,
#   99,
#   14,
#   29,
#   99,
#   67,
#   59,
#   31,
#   87,
#   77,
#   86,
#   28,
#   97,
#   88,
#   1,
#   16,
#   53,
#   5,
#   89,
#   58,
#   36,
#   63,
#   89,
#   15,
#   27,
#   72,
#   9,
#   88,
#   35,
#   95,
#   86,
#   3,
#   37,
#   29,
#   77,
#   97,
#   6,
#   1,
#   41,
#   0,
#   24,
#   45,
#   69,
#   84,
#   6,
#   20,
#   3,
#   62,
#   79,
#   9,
#   79,
#   87,
#   49,
#   87,
#   87,
#   51,
#   84,
#   45,
#   31,
#   100,
#   90,
#   34,
#   20,
#   7,
#   17,
#   29,
#   85,
#   54,
#   18,
#   42,
#   30,
#   93,
#   4,
#   46,
#   64,
#   71,
#   31,
#   2,
#   9,
#   100,
#   77,
#   24,
#   66,
#   25,
#   44,
#   76,
#   5,
#   86,
#   32,
#   23,
#   55,
#   8,
#   87,
#   29,
#   12,
#   22,
#   86,
#   66,
#   28,
#   66,
#   8,
#   39,
#   28,
#   62,
#   27,
#   90,
#   92,
#   13,
#   85,
#   44,
#   64,
#   27,
#   36,
#   92,
#   61,
#   45,
#   41,
#   56,
#   1,
#   52,
#   74,
#   32,
#   1,
#   90,
# ...

# %%
import pandas as pd

# %%
df1=pd.DataFrame(df)

# %%
df1
# Out:
#      grade  weight  friends  cousins  projects
# 0        9      68       11        8        79
# 1        2      54       14        8        77
# 2        1      60       20        8        40
# 3       99      69       12        9        64
# 4       14      62       17        8        76
# ..     ...     ...      ...      ...       ...
# 995     44      62       12        9        71
# 996     18      59       15       10        50
# 997     19      64       19        9        79
# 998     72      66       16        9        22
# 999     81      66       13        8        34
#
# [1000 rows x 5 columns]

# %%
df1.describe()
# Out:
#              grade       weight      friends      cousins    projects
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.00000
# mean     50.192000    59.938000    15.002000     9.014000    49.67500
# std      29.820872     6.002015     3.136851     0.811457    17.79635
# min       0.000000    50.000000    10.000000     8.000000    20.00000
# 25%      24.000000    55.000000    12.000000     8.000000    35.00000
# 50%      51.000000    60.000000    15.000000     9.000000    49.00000
# 75%      76.000000    65.000000    18.000000    10.000000    65.00000
# max     100.000000    70.000000    20.000000    10.000000    80.00000

# %%
df1['grade'].count()
# Out:
# 1000

# %%
df1['grade'].count
# Out:
# <bound method Series.count of 0       9
# 1       2
# 2       1
# 3      99
# 4      14
#        ..
# 995    44
# 996    18
# 997    19
# 998    72
# 999    81
# Name: grade, Length: 1000, dtype: int64>

# %%
friend18=df1['friends']>18

# %%
df1[friend18]
# Out:
#      grade  weight  friends  cousins  projects
# 2        1      60       20        8        40
# 15      88      66       19        9        43
# 21      58      64       19        8        42
# 24      89      54       19        9        38
# 25      15      54       20       10        51
# ..     ...     ...      ...      ...       ...
# 974      5      55       20       10        39
# 977     66      55       20        9        35
# 986     74      60       19       10        79
# 993     67      64       20        9        44
# 997     19      64       19        9        79
#
# [186 rows x 5 columns]

# %%
grade50=df1['grade']>50

# %%
df1[grade50]
# Out:
#      grade  weight  friends  cousins  projects
# 3       99      69       12        9        64
# 6       99      55       11        9        59
# 7       67      62       18        9        33
# 8       59      59       16       10        56
# 10      87      58       14        9        26
# ..     ...     ...      ...      ...       ...
# 986     74      60       19       10        79
# 993     67      64       20        9        44
# 994     69      56       11        9        34
# 998     72      66       16        9        22
# 999     81      66       13        8        34
#
# [502 rows x 5 columns]

# %%
df1[friend18 & grade50]
# Out:
#      grade  weight  friends  cousins  projects
# 15      88      66       19        9        43
# 21      58      64       19        8        42
# 24      89      54       19        9        38
# 37      97      57       19       10        43
# 57      51      69       20        8        48
# ..     ...     ...      ...      ...       ...
# 961     98      56       19       10        74
# 964     52      54       19        9        51
# 977     66      55       20        9        35
# 986     74      60       19       10        79
# 993     67      64       20        9        44
#
# [87 rows x 5 columns]

# %%
df1[friend18 & grade50]['weight']
# Out:
# 15     66
# 21     64
# 24     54
# 37     57
# 57     69
#        ..
# 961    56
# 964    54
# 977    55
# 986    60
# 993    64
# Name: weight, Length: 87, dtype: int64

# %%
from matplotlib import pyplot as plt

# %%
df1[ friend18 & grade50].plot()
# Out:
# <Axes: >

# %%
matplotlib inline

# %%
df1.plot()
# Out:
# <Axes: >

# %%
df1[friend18 & grade50].plot

# %%
df1[friend18 &grade50].plot(x='grade',y='weight',kind='bar',title='sample graph')
# Out:
# <Axes: title={'center': 'sample graph'}, xlabel='grade'>
